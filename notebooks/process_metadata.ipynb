# %%
import pandas as pd

from src import config
from src.metadata.metadata_process import process_metadata

df = pd.read_csv(config.METADATA_CSV)
df
# Out:
#     Nro de participante    Grupo Clasificación de caso  \
# 0            Control =        43                   NaN
# 1               Caso =        53                   NaN
# 2                     1  Control                   NaN
# 3                     2  Control                   NaN
# 4                     3     Caso    DCL MD no amnesico
# ..                  ...      ...                   ...
# 97                   97     caso       DCL no amnesico
# 98                   98     caso       DCL no amnesico
# 99                   99     caso       DCL no amnesico
# 100                 100  control                   NaN
# 101                 101  control                   NaN
#
#     Comentario (tipo de caso o criterio de exclusión) ID participante  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                   *          946462
# ...

# %%
pm = process_metadata(df)
pm
# Out:
#    subject_id sex  age group
# 0        0001   F   52    HC
# 1        0002   M   78    HC
# 2        0003   F   68   MCI
# 3        0004   F   80   MCI
# 4        0005   F   87   MCI
# ..        ...  ..  ...   ...
# 95       0097   F   75   MCI
# 96       0098   F   70   MCI
# 97       0099   F   71   MCI
# 98       0100   M   76    HC
# 99       0101   F   71    HC
#
# [100 rows x 4 columns]
