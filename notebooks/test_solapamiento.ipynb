# %%
from src.hand_analysis.loader.load_last_split import load_last_analysis

df, _ = load_last_analysis()

# %%
df
# Out:
#       subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 0              1         8     PART_A      True                          2
# 1              1         7     PART_B      True                          3
# 2              1        11     PART_A      True                          4
# 3              1        21     PART_B      True                          5
# 4              1         1     PART_A      True                          6
# ...          ...       ...        ...       ...                        ...
# 1815          99         0     PART_B      True                         17
# 1816          99        21     PART_A      True                         18
# 1817          99         3     PART_B      True                         19
# 1818          99         8     PART_A      True                         20
# 1819          99         4     PART_B     False                         21
#
#       speed_threshold  non_cut_zigzag_amplitude  non_cut_total_distance  \
# 0            0.262139                       NaN                3.756078
# 1            0.262139                 -1.134205                3.451943
# 2            0.262139                       NaN                3.522551
# 3            0.262139                 -1.470842                3.349920
# 4            0.262139                       NaN                3.910085
# ...               ...                       ...                     ...
# 1815         0.139271                 -1.166348                3.614743
# 1816         0.139271                       NaN                5.412710
# 1817         0.139271                 -1.147610                3.662643
# 1818         0.139271                       NaN                4.016559
# 1819         0.139271                       NaN                     NaN
#
#       non_cut_rt  non_cut_mean_speed  ...  wrong_targets_touches  \
# 0        18105.0            0.233577  ...                    0.0
# 1        18091.0            0.207785  ...                    1.0
# 2        15807.0            0.246373  ...                    2.0
# 3        21544.0            0.183382  ...                    0.0
# 4        18099.0            0.215457  ...                    0.0
# ...          ...                 ...  ...                    ...
# 1815     18984.0            0.210164  ...                    0.0
# 1816     21924.0            0.265528  ...                    4.0
# 1817     18612.0            0.231749  ...                    0.0
# 1818     16072.0            0.276888  ...                    0.0
# 1819         NaN                 NaN  ...                    NaN
#
#       number_of_crosses  distance_difference_from_ideal  \
# 0                   NaN                        0.035538
# 1                   NaN                        0.055096
# 2                   NaN                        0.043438
# 3                   NaN                        0.039228
# 4                   NaN                        0.036806
# ...                 ...                             ...
# 1815                NaN                        0.054127
# 1816                NaN                        0.185131
# 1817                NaN                        0.055326
# 1818                NaN                        0.061915
# 1819                NaN                             NaN
#
#       area_difference_from_ideal  intra_target_time  inter_target_time  \
# 0                       0.004123           1.181294           0.324944
# 1                       0.002956           1.195215           0.319303
# 2                       0.003559           1.052648           0.337548
# 3                       0.003385           1.418168           0.333553
# 4                       0.002579           1.378159           0.333194
# ...                          ...                ...                ...
# 1815                    0.003123           1.308280           0.342075
# 1816                    0.007645           1.553312           0.332394
# 1817                    0.003412           1.194540           0.328771
# 1818                    0.003634           1.118239           0.332653
# 1819                         NaN                NaN                NaN
#
#            invalid_cause  sex  age  group
# 0                    NaN    F   52     HC
# 1                    NaN    F   52     HC
# 2                    NaN    F   52     HC
# 3                    NaN    F   52     HC
# 4                    NaN    F   52     HC
# ...                  ...  ...  ...    ...
# 1815                 NaN    F   71    MCI
# 1816                 NaN    F   71    MCI
# 1817                 NaN    F   71    MCI
# 1818                 NaN    F   71    MCI
# 1819  CUT_CRITERIA_ERROR    F   71    MCI
#
# [1820 rows x 84 columns]

# %%
# count number of different invalid_cause

df['invalid_cause'].value_counts()
# Out:
# invalid_cause
# CUT_CRITERIA_ERROR           809
# UNABLE_TO_DETERMINE_START      1
# Name: count, dtype: int64

# %%
#show wrong_touches for subject 4
df[df['subject_id'] == 63][['trial_id', 'trial_order_of_appearance','correct_targets_touches', 'wrong_targets_touches', 'is_valid', 'invalid_cause']]
# Out:
#       trial_id  trial_order_of_appearance  correct_targets_touches  \
# 1160         7                          2                     12.0
# 1161        12                          3                      NaN
# 1162         1                          4                     12.0
# 1163        20                          5                     12.0
# 1164        11                          6                     12.0
# 1165        13                          7                     12.0
# 1166        17                          8                     12.0
# 1167         0                          9                     12.0
# 1168         5                         10                     12.0
# 1169        10                         11                     12.0
# 1170         9                         12                     12.0
# 1171        16                         13                     12.0
# 1172        15                         14                     12.0
# 1173         2                         15                     12.0
# 1174         3                         16                     12.0
# 1175         8                         17                      NaN
# 1176         6                         18                     12.0
# 1177         4                         19                     12.0
# 1178        19                         20                     12.0
# 1179        21                         21                      NaN
#
#       wrong_targets_touches  is_valid       invalid_cause
# 1160                    1.0      True                 NaN
# 1161                    NaN     False  CUT_CRITERIA_ERROR
# 1162                    0.0      True                 NaN
# 1163                    0.0      True                 NaN
# 1164                    3.0      True                 NaN
# 1165                    1.0      True                 NaN
# 1166                    0.0      True                 NaN
# 1167                    1.0      True                 NaN
# 1168                    1.0      True                 NaN
# 1169                    2.0      True                 NaN
# 1170                    0.0      True                 NaN
# 1171                    1.0      True                 NaN
# 1172                    0.0      True                 NaN
# 1173                    0.0      True                 NaN
# 1174                    0.0      True                 NaN
# 1175                    NaN     False  CUT_CRITERIA_ERROR
# 1176                    0.0      True                 NaN
# 1177                    0.0      True                 NaN
# 1178                    0.0      True                 NaN
# 1179                    NaN     False  CUT_CRITERIA_ERROR
