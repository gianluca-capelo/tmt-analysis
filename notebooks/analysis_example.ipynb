# %%
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_default_parameters
from src.metadata.add_metadata import add_metadata_to_metrics

# %%
analysis = run_analysis_with_default_parameters()
metrics_df = analysis.get_metrics_dataframe()
metrics_df.head()
# Out:
# 2025-04-05 10:33:44,771 [INFO] root: Processing subject: 0001, group: control
# 2025-04-05 10:33:44,981 [INFO] root: Processing subject: 0002, group: control
# 2025-04-05 10:33:45,185 [INFO] root: Processing subject: 0003, group: MCI
# 2025-04-05 10:33:45,330 [INFO] root: Processing subject: 0004, group: MCI
# 2025-04-05 10:33:45,521 [INFO] root: Processing subject: 0005, group: MCI
# 2025-04-05 10:33:45,741 [INFO] root: Processing subject: 0006, group: control
# 2025-04-05 10:33:45,870 [INFO] root: Processing subject: 0007, group: control
# 2025-04-05 10:33:46,018 [INFO] root: Processing subject: 0008, group: MCI
# 2025-04-05 10:33:46,248 [INFO] root: Processing subject: 0009, group: MCI
# 2025-04-05 10:33:46,382 [INFO] root: Processing subject: 0010, group: control
# 2025-04-05 10:33:46,513 [INFO] root: Processing subject: 0011, group: MCI
# 2025-04-05 10:33:46,791 [INFO] root: Processing subject: 0012, group: MCI
# 2025-04-05 10:33:46,944 [INFO] root: Processing subject: 0013, group: MCI
# 2025-04-05 10:33:47,083 [INFO] root: Processing subject: 0014, group: control
# 2025-04-05 10:33:47,342 [INFO] root: Processing subject: 0015, group: MCI
# 2025-04-05 10:33:47,486 [INFO] root: Processing subject: 0016, group: MCI
# 2025-04-05 10:33:47,614 [INFO] root: Processing subject: 0017, group: MCI
# 2025-04-05 10:33:47,745 [INFO] root: Processing subject: 0018, group: control
# 2025-04-05 10:33:48,041 [INFO] root: Processing subject: 0019, group: MCI
# 2025-04-05 10:33:48,191 [INFO] root: Processing subject: 0020, group: MCI
# 2025-04-05 10:33:48,333 [INFO] root: Processing subject: 0021, group: control
# 2025-04-05 10:33:48,459 [INFO] root: Processing subject: 0022, group: control
# 2025-04-05 10:33:48,592 [INFO] root: Processing subject: 0023, group: control
# 2025-04-05 10:33:48,936 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-04-05 10:33:49,074 [INFO] root: Processing subject: 0025, group: MCI
# 2025-04-05 10:33:49,231 [INFO] root: Processing subject: 0026, group: control
# 2025-04-05 10:33:49,360 [INFO] root: Processing subject: 0027, group: MCI
# 2025-04-05 10:33:49,503 [INFO] root: Processing subject: 0028, group: control
# 2025-04-05 10:33:49,629 [INFO] root: Processing subject: 0029, group: control
# 2025-04-05 10:33:50,012 [INFO] root: Processing subject: 0030, group: control
# 2025-04-05 10:33:50,154 [INFO] root: Processing subject: 0031, group: control
# 2025-04-05 10:33:50,307 [INFO] root: Processing subject: 0032, group: control
# 2025-04-05 10:33:50,424 [INFO] root: Processing subject: 0033, group: control
# 2025-04-05 10:33:50,569 [INFO] root: Processing subject: 0034, group: control
# 2025-04-05 10:33:50,705 [INFO] root: Processing subject: 0035, group: control
# 2025-04-05 10:33:50,848 [INFO] root: Processing subject: 0036, group: control
# 2025-04-05 10:33:50,982 [INFO] root: Processing subject: 0037, group: control
# 2025-04-05 10:33:51,388 [INFO] root: Processing subject: 0038, group: control
# 2025-04-05 10:33:51,515 [INFO] root: Processing subject: 0039, group: control
# 2025-04-05 10:33:51,645 [INFO] root: Processing subject: 0040, group: control
# 2025-04-05 10:33:51,778 [INFO] root: Processing subject: 0041, group: control
# 2025-04-05 10:33:51,895 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-04-05 10:33:52,029 [INFO] root: Processing subject: 0043, group: control
# 2025-04-05 10:33:52,159 [INFO] root: Processing subject: 0044, group: control
# 2025-04-05 10:33:52,288 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-04-05 10:33:52,425 [INFO] root: Processing subject: 0046, group: MCI
# 2025-04-05 10:33:52,925 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-04-05 10:33:53,055 [INFO] root: Processing subject: 0048, group: MCI
# 2025-04-05 10:33:53,197 [INFO] root: Processing subject: 0049, group: MCI
# 2025-04-05 10:33:53,338 [INFO] root: Processing subject: 0050, group: MCI
# 2025-04-05 10:33:53,445 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 10:33:53,478 [INFO] root: Processing subject: 0051, group: MCI
# 2025-04-05 10:33:53,601 [INFO] root: Processing subject: 0052, group: MCI
# 2025-04-05 10:33:53,741 [INFO] root: Processing subject: 0053, group: MCI
# 2025-04-05 10:33:53,845 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 10:33:53,848 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 10:33:53,874 [INFO] root: Processing subject: 0054, group: MCI
# 2025-04-05 10:33:54,012 [INFO] root: Processing subject: 0055, group: MCI
# 2025-04-05 10:33:54,134 [INFO] root: Processing subject: 0056, group: control
# 2025-04-05 10:33:54,273 [INFO] root: Processing subject: 0057, group: MCI
# 2025-04-05 10:33:54,845 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-04-05 10:33:54,984 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-04-05 10:33:55,113 [INFO] root: Processing subject: 0060, group: MCI
# 2025-04-05 10:33:55,255 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-04-05 10:33:55,386 [INFO] root: Processing subject: 0062, group: MCI
# 2025-04-05 10:33:55,491 [INFO] root: Processing subject: 0063, group: control
# 2025-04-05 10:33:55,614 [INFO] root: Processing subject: 0064, group: MCI
# 2025-04-05 10:33:55,759 [INFO] root: Processing subject: 0065, group: MCI
# 2025-04-05 10:33:55,894 [INFO] root: Processing subject: 0066, group: MCI
# 2025-04-05 10:33:56,046 [INFO] root: Processing subject: 0067, group: MCI
# 2025-04-05 10:33:56,175 [INFO] root: Processing subject: 0068, group: MCI
# 2025-04-05 10:33:56,317 [INFO] root: Processing subject: 0069, group: MCI
# 2025-04-05 10:33:56,437 [INFO] root: Processing subject: 0070, group: control
# 2025-04-05 10:33:56,568 [INFO] root: Processing subject: 0071, group: control
# 2025-04-05 10:33:57,271 [INFO] root: Processing subject: 0072, group: MCI
# 2025-04-05 10:33:57,398 [INFO] root: Processing subject: 0073, group: MCI
# 2025-04-05 10:33:57,542 [INFO] root: Processing subject: 0074, group: control
# 2025-04-05 10:33:57,659 [INFO] root: Processing subject: 0075, group: MCI
# 2025-04-05 10:33:57,797 [INFO] root: Processing subject: 0076, group: MCI
# 2025-04-05 10:33:57,920 [INFO] root: Processing subject: 0077, group: MCI
# 2025-04-05 10:33:58,049 [INFO] root: Processing subject: 0078, group: control
# 2025-04-05 10:33:58,190 [INFO] root: Processing subject: 0079, group: control
# 2025-04-05 10:33:58,347 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 10:33:58,364 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-04-05 10:33:58,500 [INFO] root: Processing subject: 0081, group: MCI
# 2025-04-05 10:33:58,632 [INFO] root: Processing subject: 0082, group: MCI
# 2025-04-05 10:33:58,768 [INFO] root: Processing subject: 0083, group: control
# 2025-04-05 10:33:58,898 [INFO] root: Processing subject: 0084, group: control
# 2025-04-05 10:33:59,037 [INFO] root: Processing subject: 0085, group: control
# 2025-04-05 10:33:59,162 [INFO] root: Processing subject: 0086, group: control
# 2025-04-05 10:33:59,298 [INFO] root: Processing subject: 0087, group: control
# 2025-04-05 10:34:00,069 [INFO] root: Processing subject: 0088, group: MCI
# 2025-04-05 10:34:00,218 [INFO] root: Processing subject: 0089, group: control
# 2025-04-05 10:34:00,356 [INFO] root: Processing subject: 0090, group: control
# 2025-04-05 10:34:00,487 [INFO] root: Processing subject: 0091, group: control
# 2025-04-05 10:34:00,610 [INFO] root: Processing subject: 0092, group: MCI
# 2025-04-05 10:34:00,754 [INFO] root: Processing subject: 0093, group: MCI
# 2025-04-05 10:34:00,896 [INFO] root: Processing subject: 0094, group: MCI
# 2025-04-05 10:34:01,043 [INFO] root: Processing subject: 0095, group: control
# 2025-04-05 10:34:01,174 [INFO] root: Processing subject: 0096, group: MCI
# 2025-04-05 10:34:01,317 [INFO] root: Processing subject: 0097, group: MCI
# 2025-04-05 10:34:01,448 [INFO] root: Processing subject: 0098, group: MCI
# 2025-04-05 10:34:01,582 [INFO] root: Processing subject: 0099, group: MCI
# 2025-04-05 10:34:01,711 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-04-05 10:34:07,824 [ERROR] root: Error processing trial 12 for subject 0076: 'bool' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 89, in generate_rows_for_subject
#     trial_metrics = compute_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 239, in compute_trial_metrics
#     segmentation = calculate_segmentation_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 321, in calculate_segmentation_trial_metrics
#     classified_positions = classify_cursor_positions_with_hesitation(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 93, in classify_cursor_positions_with_hesitation
#     over_target = over_target_flags[i][0]
# TypeError: 'bool' object is not subscriptable
# 2025-04-05 10:34:08,037 [ERROR] root: Error processing subject 0079: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-05 10:34:09,474 [INFO] root: Metrics successfully saved to /home/gianluca/Research/tmt-analysis/data/hand_analysis/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                          2         0.262139        3.756078  18105  ...
# 1                          3         0.262139        3.451943  18091  ...
# 2                          4         0.262139        3.522551  15807  ...
# 3                          5         0.262139        3.349920  21544  ...
# 4                          6         0.262139        3.910085  18099  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.702588          0.215688               26.0          0.654418
# 1          0.427423          0.162585               25.0          0.203475
# 2          0.554113          0.184134               24.0          0.000000
# 3          0.455928          0.140833               26.0          0.000000
# 4          0.542851          0.153982               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    number_of_crosses  invalid_cause
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
# [5 rows x 41 columns]
# Len of subjects: 99
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                          2         0.262139        3.756078  18105  ...
# 1                          3         0.262139        3.451943  18091  ...
# 2                          4         0.262139        3.522551  15807  ...
# 3                          5         0.262139        3.349920  21544  ...
# 4                          6         0.262139        3.910085  18099  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.702588          0.215688               26.0          0.654418
# 1          0.427423          0.162585               25.0          0.203475
# 2          0.554113          0.184134               24.0          0.000000
# 3          0.455928          0.140833               26.0          0.000000
# 4          0.542851          0.153982               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    number_of_crosses  invalid_cause
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
# [5 rows x 41 columns]

# %%
metrics_df = add_metadata_to_metrics(metrics_df)
metrics_df.head()
# Out:
# /home/gianluca/Research/tmt-analysis/src/metadata/metadata_process.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   process_df = process_df[metadata_df['Nro de participante'] != 'Caso = ']
#   subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 0       0001         8     PART_A      True                          2
# 1       0001         7     PART_B      True                          3
# 2       0001        11     PART_A      True                          4
# 3       0001        21     PART_B      True                          5
# 4       0001         1     PART_A      True                          6
#
#    speed_threshold  total_distance     rt  correct_targets_touches  \
# 0         0.262139        3.756078  18105                     15.0
# 1         0.262139        3.451943  18091                     15.0
# 2         0.262139        3.522551  15807                     15.0
# 3         0.262139        3.349920  21544                     15.0
# 4         0.262139        3.910085  18099                     15.0
#
#    wrong_targets_touches  ...  hesitation_ratio  total_hesitations  \
# 0                    3.0  ...          0.654418                1.0
# 1                    3.0  ...          0.203475                1.0
# 2                    4.0  ...          0.000000                0.0
# 3                    4.0  ...          0.000000                0.0
# 4                    4.0  ...          0.000000                0.0
#
#    average_duration  max_duration    hesitation_periods  number_of_crosses  \
# 0          4.333857      4.333857   [4.333857099999932]                NaN
# 1          0.735873      0.735873  [0.7358727999999246]                NaN
# 2          0.000000      0.000000                    []                NaN
# 3          0.000000      0.000000                    []                NaN
# 4          0.000000      0.000000                    []                NaN
#
#    invalid_cause  sex  age  group
# 0            NaN    F   52     HC
# 1            NaN    F   52     HC
# 2            NaN    F   52     HC
# 3            NaN    F   52     HC
# 4            NaN    F   52     HC
#
# [5 rows x 42 columns]

# %%
metrics_df
# Out:
#      subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 0          0001         8     PART_A      True                          2
# 1          0001         7     PART_B      True                          3
# 2          0001        11     PART_A      True                          4
# 3          0001        21     PART_B      True                          5
# 4          0001         1     PART_A      True                          6
# ...         ...       ...        ...       ...                        ...
# 1935       0099         0     PART_B      True                         17
# 1936       0099        21     PART_A      True                         18
# 1937       0099         3     PART_B      True                         19
# 1938       0099         8     PART_A      True                         20
# 1939       0099         4     PART_B      True                         21
#
#       speed_threshold  total_distance     rt  correct_targets_touches  \
# 0            0.262139        3.756078  18105                     15.0
# 1            0.262139        3.451943  18091                     15.0
# 2            0.262139        3.522551  15807                     15.0
# 3            0.262139        3.349920  21544                     15.0
# 4            0.262139        3.910085  18099                     15.0
# ...               ...             ...    ...                      ...
# 1935         0.139271        3.614743  18984                     15.0
# 1936         0.139271        5.412710  21924                     15.0
# 1937         0.139271        3.662643  18612                     15.0
# 1938         0.139271        4.016559  16072                     15.0
# 1939         0.139271        4.013071  25002                     10.0
#
#       wrong_targets_touches  ...  hesitation_ratio  total_hesitations  \
# 0                       3.0  ...          0.654418                1.0
# 1                       3.0  ...          0.203475                1.0
# 2                       4.0  ...          0.000000                0.0
# 3                       4.0  ...          0.000000                0.0
# 4                       4.0  ...          0.000000                0.0
# ...                     ...  ...               ...                ...
# 1935                    2.0  ...          0.000000                0.0
# 1936                   12.0  ...          0.497201                5.0
# 1937                    3.0  ...          0.019453                1.0
# 1938                    1.0  ...          0.175622                1.0
# 1939                    4.0  ...          0.526119                3.0
#
#       average_duration  max_duration  \
# 0             4.333857      4.333857
# 1             0.735873      0.735873
# 2             0.000000      0.000000
# 3             0.000000      0.000000
# 4             0.000000      0.000000
# ...                ...           ...
# 1935          0.000000      0.000000
# 1936          0.780583      1.766734
# 1937          0.069026      0.069026
# 1938          0.733461      0.733461
# 1939          1.644547      4.233474
#
#                                      hesitation_periods  number_of_crosses  \
# 0                                   [4.333857099999932]                NaN
# 1                                  [0.7358727999999246]                NaN
# 2                                                    []                NaN
# 3                                                    []                NaN
# 4                                                    []                NaN
# ...                                                 ...                ...
# 1935                                                 []                NaN
# 1936  [0.3000841001048684, 1.766733500175178, 1.4024...                NaN
# 1937                              [0.06902600033208728]                NaN
# 1938                               [0.7334607001394033]                NaN
# 1939  [0.16667989967390895, 4.233474400360137, 0.533...                NaN
#
#       invalid_cause  sex  age  group
# 0               NaN    F   52     HC
# 1               NaN    F   52     HC
# 2               NaN    F   52     HC
# 3               NaN    F   52     HC
# 4               NaN    F   52     HC
# ...             ...  ...  ...    ...
# 1935            NaN    F   71    MCI
# 1936            NaN    F   71    MCI
# 1937            NaN    F   71    MCI
# 1938            NaN    F   71    MCI
# 1939            NaN    F   71    MCI
#
# [1940 rows x 42 columns]
