# %%
from src.hand_analysis.loader.load_last_split import load_last_analysis

train_set, eval_set = load_last_analysis()

# %%
train_set['group'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='group'>

# %%
eval_set['group'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='group'>
