# %%
from src import config
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_configuration_parameters

analysis = run_analysis_with_configuration_parameters(config.DATA_DIR)
experiment = analysis.experiment
# Out:
# 2025-04-25 19:35:02,278 [INFO] root: Processing subject: 0001, group: control
# 2025-04-25 19:35:02,489 [INFO] root: Processing subject: 0002, group: control
# 2025-04-25 19:35:02,690 [INFO] root: Processing subject: 0003, group: MCI
# 2025-04-25 19:35:02,835 [INFO] root: Processing subject: 0004, group: MCI
# 2025-04-25 19:35:03,029 [INFO] root: Processing subject: 0005, group: MCI
# 2025-04-25 19:35:03,249 [INFO] root: Processing subject: 0006, group: control
# 2025-04-25 19:35:03,376 [INFO] root: Processing subject: 0007, group: control
# 2025-04-25 19:35:03,513 [INFO] root: Processing subject: 0008, group: MCI
# 2025-04-25 19:35:03,732 [INFO] root: Processing subject: 0009, group: MCI
# 2025-04-25 19:35:03,861 [INFO] root: Processing subject: 0010, group: control
# 2025-04-25 19:35:03,976 [INFO] root: Processing subject: 0011, group: MCI
# 2025-04-25 19:35:04,230 [INFO] root: Processing subject: 0012, group: MCI
# 2025-04-25 19:35:04,367 [INFO] root: Processing subject: 0013, group: MCI
# 2025-04-25 19:35:04,498 [INFO] root: Processing subject: 0014, group: control
# 2025-04-25 19:35:04,752 [INFO] root: Processing subject: 0015, group: MCI
# 2025-04-25 19:35:04,906 [INFO] root: Processing subject: 0016, group: MCI
# 2025-04-25 19:35:05,038 [INFO] root: Processing subject: 0017, group: MCI
# 2025-04-25 19:35:05,175 [INFO] root: Processing subject: 0018, group: control
# 2025-04-25 19:35:05,471 [INFO] root: Processing subject: 0019, group: MCI
# 2025-04-25 19:35:05,616 [INFO] root: Processing subject: 0020, group: MCI
# 2025-04-25 19:35:05,760 [INFO] root: Processing subject: 0021, group: control
# 2025-04-25 19:35:05,893 [INFO] root: Processing subject: 0022, group: control
# 2025-04-25 19:35:06,031 [INFO] root: Processing subject: 0023, group: control
# 2025-04-25 19:35:06,377 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-04-25 19:35:06,521 [INFO] root: Processing subject: 0025, group: MCI
# 2025-04-25 19:35:06,675 [INFO] root: Processing subject: 0026, group: control
# 2025-04-25 19:35:06,814 [INFO] root: Processing subject: 0027, group: MCI
# 2025-04-25 19:35:06,971 [INFO] root: Processing subject: 0028, group: control
# 2025-04-25 19:35:07,125 [INFO] root: Processing subject: 0029, group: control
# 2025-04-25 19:35:07,519 [INFO] root: Processing subject: 0030, group: control
# 2025-04-25 19:35:07,661 [INFO] root: Processing subject: 0031, group: control
# 2025-04-25 19:35:07,810 [INFO] root: Processing subject: 0032, group: control
# 2025-04-25 19:35:07,933 [INFO] root: Processing subject: 0033, group: control
# 2025-04-25 19:35:08,075 [INFO] root: Processing subject: 0034, group: control
# 2025-04-25 19:35:08,213 [INFO] root: Processing subject: 0035, group: control
# 2025-04-25 19:35:08,350 [INFO] root: Processing subject: 0036, group: control
# 2025-04-25 19:35:08,481 [INFO] root: Processing subject: 0037, group: control
# 2025-04-25 19:35:08,896 [INFO] root: Processing subject: 0038, group: control
# 2025-04-25 19:35:09,023 [INFO] root: Processing subject: 0039, group: control
# 2025-04-25 19:35:09,158 [INFO] root: Processing subject: 0040, group: control
# 2025-04-25 19:35:09,294 [INFO] root: Processing subject: 0041, group: control
# 2025-04-25 19:35:09,417 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-04-25 19:35:09,556 [INFO] root: Processing subject: 0043, group: control
# 2025-04-25 19:35:09,687 [INFO] root: Processing subject: 0044, group: control
# 2025-04-25 19:35:09,819 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-04-25 19:35:09,964 [INFO] root: Processing subject: 0046, group: MCI
# 2025-04-25 19:35:10,487 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-04-25 19:35:10,620 [INFO] root: Processing subject: 0048, group: MCI
# 2025-04-25 19:35:10,763 [INFO] root: Processing subject: 0049, group: MCI
# 2025-04-25 19:35:10,914 [INFO] root: Processing subject: 0050, group: MCI
# 2025-04-25 19:35:11,024 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-25 19:35:11,055 [INFO] root: Processing subject: 0051, group: MCI
# 2025-04-25 19:35:11,184 [INFO] root: Processing subject: 0052, group: MCI
# 2025-04-25 19:35:11,335 [INFO] root: Processing subject: 0053, group: MCI
# 2025-04-25 19:35:11,434 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-25 19:35:11,437 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-25 19:35:11,461 [INFO] root: Processing subject: 0054, group: MCI
# 2025-04-25 19:35:11,602 [INFO] root: Processing subject: 0055, group: MCI
# 2025-04-25 19:35:11,734 [INFO] root: Processing subject: 0056, group: control
# 2025-04-25 19:35:11,877 [INFO] root: Processing subject: 0057, group: MCI
# 2025-04-25 19:35:12,462 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-04-25 19:35:12,619 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-04-25 19:35:12,759 [INFO] root: Processing subject: 0060, group: MCI
# 2025-04-25 19:35:12,906 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-04-25 19:35:13,042 [INFO] root: Processing subject: 0062, group: MCI
# 2025-04-25 19:35:13,154 [INFO] root: Processing subject: 0063, group: control
# 2025-04-25 19:35:13,281 [INFO] root: Processing subject: 0064, group: MCI
# 2025-04-25 19:35:13,424 [INFO] root: Processing subject: 0065, group: MCI
# 2025-04-25 19:35:13,561 [INFO] root: Processing subject: 0066, group: MCI
# 2025-04-25 19:35:13,728 [INFO] root: Processing subject: 0067, group: MCI
# 2025-04-25 19:35:13,867 [INFO] root: Processing subject: 0068, group: MCI
# 2025-04-25 19:35:14,025 [INFO] root: Processing subject: 0069, group: MCI
# 2025-04-25 19:35:14,152 [INFO] root: Processing subject: 0070, group: control
# 2025-04-25 19:35:14,295 [INFO] root: Processing subject: 0071, group: control
# 2025-04-25 19:35:14,966 [INFO] root: Processing subject: 0072, group: MCI
# 2025-04-25 19:35:15,099 [INFO] root: Processing subject: 0073, group: MCI
# 2025-04-25 19:35:15,250 [INFO] root: Processing subject: 0074, group: control
# 2025-04-25 19:35:15,371 [INFO] root: Processing subject: 0075, group: MCI
# 2025-04-25 19:35:15,513 [INFO] root: Processing subject: 0076, group: MCI
# 2025-04-25 19:35:15,647 [INFO] root: Processing subject: 0077, group: MCI
# 2025-04-25 19:35:15,781 [INFO] root: Processing subject: 0078, group: control
# 2025-04-25 19:35:15,924 [INFO] root: Processing subject: 0079, group: control
# 2025-04-25 19:35:16,078 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-25 19:35:16,096 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-04-25 19:35:16,234 [INFO] root: Processing subject: 0081, group: MCI
# 2025-04-25 19:35:16,368 [INFO] root: Processing subject: 0082, group: MCI
# 2025-04-25 19:35:16,506 [INFO] root: Processing subject: 0083, group: control
# 2025-04-25 19:35:16,639 [INFO] root: Processing subject: 0084, group: control
# 2025-04-25 19:35:16,783 [INFO] root: Processing subject: 0085, group: control
# 2025-04-25 19:35:16,917 [INFO] root: Processing subject: 0086, group: control
# 2025-04-25 19:35:17,057 [INFO] root: Processing subject: 0087, group: control
# 2025-04-25 19:35:17,179 [INFO] root: Processing subject: 0088, group: MCI
# 2025-04-25 19:35:17,995 [INFO] root: Processing subject: 0089, group: control
# 2025-04-25 19:35:18,139 [INFO] root: Processing subject: 0090, group: control
# 2025-04-25 19:35:18,277 [INFO] root: Processing subject: 0091, group: control
# 2025-04-25 19:35:18,402 [INFO] root: Processing subject: 0092, group: MCI
# 2025-04-25 19:35:18,549 [INFO] root: Processing subject: 0093, group: MCI
# 2025-04-25 19:35:18,690 [INFO] root: Processing subject: 0094, group: MCI
# 2025-04-25 19:35:18,837 [INFO] root: Processing subject: 0095, group: control
# 2025-04-25 19:35:18,970 [INFO] root: Processing subject: 0096, group: MCI
# 2025-04-25 19:35:19,105 [INFO] root: Processing subject: 0097, group: MCI
# 2025-04-25 19:35:19,236 [INFO] root: Processing subject: 0098, group: MCI
# 2025-04-25 19:35:19,372 [INFO] root: Processing subject: 0099, group: MCI
# 2025-04-25 19:35:19,506 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-04-25 19:35:26,083 [ERROR] root: Error processing trial 12 for subject 0076: 'bool' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 89, in generate_rows_for_subject
#     trial_metrics = compute_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 239, in compute_trial_metrics
#     segmentation = calculate_segmentation_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 321, in calculate_segmentation_trial_metrics
#     classified_positions = classify_cursor_positions_with_hesitation(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 93, in classify_cursor_positions_with_hesitation
#     over_target = over_target_flags[i][0]
# TypeError: 'bool' object is not subscriptable
# 2025-04-25 19:35:26,322 [ERROR] root: Error processing subject 0079: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-25 19:35:28,000 [INFO] root: Metrics successfully saved to /home/gianluca/Research/tmt-analysis/data/hand_analysis/analysis.csv/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                          2         0.262139        3.756078  18105  ...
# 1                          3         0.262139        3.451943  18091  ...
# 2                          4         0.262139        3.522551  15807  ...
# 3                          5         0.262139        3.349920  21544  ...
# 4                          6         0.262139        3.910085  18099  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.702588          0.215688               26.0          0.654418
# 1          0.427423          0.162585               25.0          0.203475
# 2          0.554113          0.184134               24.0          0.000000
# 3          0.455928          0.140833               26.0          0.000000
# 4          0.542851          0.153982               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    number_of_crosses  invalid_cause
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
# [5 rows x 41 columns]
# Len of subjects: 99

# %%
subject = experiment.subjects["0063"]
subject
# Out:
# TMTSubject(training_trials=[], testing_trials=[TMTTrial(stimuli=[TMTTarget(content='1', position=Coordinate(x=-0.20191733333333317, y=-0.2820346666666667)), TMTTarget(content='2', position=Coordinate(x=-0.1183973333333332, y=-0.3655546666666667)), TMTTarget(content='3', position=Coordinate(x=-0.14623733333333336, y=-0.1706746666666666)), TMTTarget(content='4', position=Coordinate(x=-0.25759733333333334, y=-0.11499466666666662)), TMTTarget(content='5', position=Coordinate(x=-0.007037333333333234, y=-0.1706746666666666)), TMTTarget(content='6', position=Coordinate(x=0.16000266666666654, y=-0.11499466666666662)), TMTTarget(content='7', position=Coordinate(x=0.2435226666666667, y=0.13556533333333332)), TMTTarget(content='8', position=Coordinate(x=0.38272266666666666, y=0.24692533333333327)), TMTTarget(content='9', position=Coordinate(x=0.2713626666666667, y=-0.059314666666666634)), TMTTarget(content='10', position=Coordinate(x=0.41056266666666663, y=0.1634053333333333)), TMTTarget(content='11', position=Coordinate(x=0.46624266666666664, y=0.24692533333333327)), TMTTarget(content='12', position=Coordinate(x=0.2713626666666667, y=0.3861253333333332)), TMTTarget(content='13', position=Coordinate(x=0.020802666666666757, y=0.1912453333333333)), TMTTarget(content='14', position=Coordinate(x=-0.20191733333333317, y=0.35828533333333323)), TMTTarget(content='15', position=Coordinate(x=-0.20191733333333317, y=0.07988533333333332))], cursor_trail=[CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.0002255002036690712), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.02269470039755106), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.055717500392347574), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.08912819996476173), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.122365300077945), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.15574980014935136), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.18902460020035505), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.22236989997327328), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.2557093002833426), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.2890464002266526), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.3223895002156496), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.35573070030659437), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.3890311000868678), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.42241070000454783), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.4557386999949813), CursorInfo(position=Coordinate(x=0.0027777778, y=0.0064814813), time=0.4891075002960861), CursorInfo(position=Coordinate(x=-0.0009259259, y=0.011111111), time=0.5225701001472771), CursorInfo(position=Coordinate(x=-0.013888889, y=0.039814815), time=0.5560930999927223), CursorInfo(position=Coordinate(x=-0.025925925, y=0.07037037), time=0.5892762001603842), CursorInfo(position=Coordinate(x=-0.030555556, y=0.08240741), time=0.6226226002909243), CursorInfo(position=Coordinate(x=-0.04074074, y=0.096296296), time=0.6559327002614737), CursorInfo(position=Coordinate(x=-0.042592593, y=0.107407406), time=0.689283000305295), CursorInfo(position=Coordinate(x=-0.04537037, y=0.11851852), time=0.7226037001237273), CursorInfo(position=Coordinate(x=-0.046296295, y=0.12037037), time=0.7558893002569675), CursorInfo(position=Coordinate(x=-0.046296295, y=0.12314815), time=0.7892574002034962), CursorInfo(position=Coordinate(x=-0.044444446, y=0.12777779), time=0.8226126004010439), CursorInfo(position=Coordinate(x=-0.03888889, y=0.13333334), time=0.855906100012362), CursorInfo(position=Coordinate(x=-0.035185184, y=0.13518518), time=0.8892479003407061), CursorInfo(position=Coordinate(x=-0. ...

# %%
from neurotask.tmt.metrics import calculate_speeds_between_cursor_positions, \
    calculate_accelerations_between_cursor_positions
from matplotlib import pyplot as plt
from build.lib.neurotask.tmt.model.tmt_model import TMTTrial


def plot_with_color(trial: TMTTrial, canvas_size: int, target_radius: float, color_by='time'):
    """
    Plotea la trayectoria del cursor junto con los targets en un gráfico,
    ajustando el tamaño del gráfico al tamaño del canvas y dibujando círculos
    alrededor de los targets con su contenido. La trayectoria del cursor se
    dibuja con puntos cuyos colores cambian en función del tiempo, la velocidad o la aceleración.
    El primer clic en el target se destaca con un marcador especial.

    Parameters:
    - trial: TMTTrial, el trial con la trayectoria del cursor y los targets.
    - canvas_size: int, tamaño del canvas (ancho y alto).
    - target_radius: float, radio de los círculos que rodean los targets.
    - color_by: str, 'time', 'speed' o 'acceleration', determina si el color de los puntos cambia en función del tiempo, velocidad o aceleración.
    """

    # Extraer la posición de los targets
    target_x = [target.position.x for target in trial.stimuli]
    target_y = [target.position.y for target in trial.stimuli]
    target_contents = [target.content for target in trial.stimuli]

    cursor_trail_from_first_click = trial.get_cursor_trail_from_start()
    # Extraer la trayectoria del cursor
    cursor_x = [cursor_info.position.x for cursor_info in cursor_trail_from_first_click]
    cursor_y = [cursor_info.position.y for cursor_info in cursor_trail_from_first_click]
    cursor_times = [cursor_info.time for cursor_info in cursor_trail_from_first_click]

    if color_by == 'time':
        # Normalizar tiempos para que estén en el rango [0, 1]
        norm = plt.Normalize(min(cursor_times), max(cursor_times))
        colors = plt.cm.viridis(norm(cursor_times))  # Usar un mapa de colores para el tiempo
    elif color_by == 'speed':
        speeds = calculate_speeds_between_cursor_positions(trial)
        speeds = [0] + speeds  # Para igualar el número de puntos con las velocidades calculadas
        norm = plt.Normalize(min(speeds), max(speeds))
        colors = plt.cm.viridis(norm(speeds))  # Usar un mapa de colores para la velocidad
    elif color_by == 'acceleration':
        accelerations = calculate_accelerations_between_cursor_positions(trial)
        accelerations = [0, 0] + accelerations  # Igualar el número de puntos (2 primeros puntos sin aceleración)
        norm = plt.Normalize(min(accelerations), max(accelerations))
        colors = plt.cm.viridis(norm(accelerations))  # Usar un mapa de colores para la aceleración
    else:
        raise ValueError("El parámetro color_by debe ser 'time', 'speed' o 'acceleration'.")

    # Crear el gráfico
    fig, ax = plt.subplots(figsize=(8, 8))

    # Dibujar la trayectoria del cursor como líneas coloreadas por tiempo o velocidad
    for i in range(len(cursor_x) - 1):
        plt.plot([cursor_x[i], cursor_x[i + 1]],
                 [cursor_y[i], cursor_y[i + 1]],
                 color=colors[i], linewidth=2, zorder=4)

    # Dibujar los targets como círculos con el contenido dentro
    for x, y, content in zip(target_x, target_y, target_contents):
        circle = plt.Circle((x, y), target_radius, color='red', alpha=0.3, zorder=5)
        plt.gca().add_patch(circle)
        # Añadir el contenido del target en el centro del círculo
        plt.text(x, y, content, color='black', fontsize=8, ha='center', va='center', zorder=6)

    # Destacar el primer clic
    if trial.start:
        fc_x = trial.start.position.x
        fc_y = trial.start.position.y
        plt.scatter(fc_x, fc_y, color='cyan', edgecolor='black', s=100, label='First Click', zorder=7,
                    marker='o', alpha=0.3)

    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar_label = 'Time' if color_by == 'time' else 'Speed' if color_by == 'speed' else 'Acceleration'
    cbar = fig.colorbar(sm, ax=ax, label=cbar_label)

    # # Set plot limits based on canvas size
    # ax.set_xlim(-canvas_size, canvas_size)
    # ax.set_ylim(canvas_size, -canvas_size,)  # Inverted Y-axis if needed

    # Add labels and title
    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.set_title('Cursor Trail with Targets')

    # Ensure equal aspect ratio
    ax.set_aspect('equal', adjustable='box')

    # Add legend
    ax.legend()

    return fig

# %%
from src.hand_analysis.loader.load_last_split import load_last_analysis
train_set, _ = load_last_analysis()
subject_analysis = train_set[train_set['subject_id'] == 63]
subject_analysis
# Out:
# 2025-04-25 19:48:02,085 [INFO] root: Loading split from /home/gianluca/Research/tmt-analysis/data/hand_analysis/2025-04-25_13-41-47
#      subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 980          63         7     PART_A      True                          2
# 981          63        12     PART_B      True                          3
# 982          63         1     PART_A      True                          4
# 983          63        20     PART_B      True                          5
# 984          63        11     PART_A      True                          6
# 985          63        13     PART_B      True                          7
# 986          63        17     PART_A      True                          8
# 987          63         0     PART_B      True                          9
# 988          63         5     PART_A      True                         10
# 989          63        10     PART_B      True                         11
# 990          63         9     PART_A      True                         12
# 991          63        16     PART_B      True                         13
# 992          63        15     PART_A      True                         14
# 993          63         2     PART_B      True                         15
# 994          63         3     PART_A      True                         16
# 995          63         8     PART_B      True                         17
# 996          63         6     PART_A      True                         18
# 997          63         4     PART_B      True                         19
# 998          63        19     PART_A      True                         20
# 999          63        21     PART_B      True                         21
#
#      speed_threshold  total_distance     rt  correct_targets_touches  \
# 980         0.204387        3.329216  20958                     15.0
# 981         0.204387        2.509790  25028                     10.0
# 982         0.204387        5.191925  23676                     14.0
# 983         0.204387        3.428806  22257                     15.0
# 984         0.204387        3.653822  19301                     15.0
# 985         0.204387        3.733872  18216                     15.0
# 986         0.204387        3.023647  17425                     15.0
# 987         0.204387        3.661062  20223                     14.0
# 988         0.204387        4.285932  18688                     15.0
# 989         0.204387        3.840618  22569                     15.0
# 990         0.204387        3.883930  20409                     15.0
# 991         0.204387        3.408843  20606                     15.0
# 992         0.204387        3.663504  18301                     15.0
# 993         0.204387        3.169733  15028                     15.0
# 994         0.204387        3.541404  15381                     15.0
# 995         0.204387        4.312437  25002                      8.0
# 996         0.204387        3.964442  19205                     15.0
# 997         0.204387        3.827544  19700                     15.0
# 998         0.204387        4.297040  24433                     15.0
# 999         0.204387        3.414364  25021                      8.0
#
#      wrong_targets_touches  ...  hesitation_ratio  total_hesitations  \
# 980                    3.0  ...          0.185277                3.0
# 981                    0.0  ...          0.000000                0.0
# 982                    8.0  ...          0.266739                4.0
# 983                    3.0  ...          0.065441                1.0
# 984                    3.0  ...          0.000000                0.0
# 985                    2.0  ...          0.000000                0.0
# 986                    3.0  ...          0.000000                0.0
# 987                    3.0  ...          0.124510                2.0
# 988                    5.0  ...          0.310341                2.0
# 989                    5.0  ...          0.012562                1.0
# 990                    0.0  ...          0.282590                1.0
# 991                    1.0  ...          0.254140                1.0
# 992                    1.0  ...          0.000000                0.0
# 993                    1.0  ...          0.000000                0.0
# 994                    5.0  ...          0.000000                0.0
# 995                   10.0  ...          0.542682                6.0
# 996                    2.0  ...          0.000000                0.0
# 997                    2.0  ...          0.278315                2.0
# 998                    7.0  ...          0.183340                2.0
# 999                   12.0  ...          0.748819                5.0
#
#      average_duration  max_duration  \
# 980          0.177911      0.233523
# 981          0.000000      0.000000
# 982          0.300005      0.833533
# 983          0.168803      0.168803
# 984          0.000000      0.000000
# 985          0.000000      0.000000
# 986          0.000000      0.000000
# 987          0.183428      0.333517
# 988          0.566851      0.666874
# 989          0.033307      0.033307
# 990          0.766868      0.766868
# 991          0.935844      0.935844
# 992          0.000000      0.000000
# 993          0.000000      0.000000
# 994          0.000000      0.000000
# 995          1.022443      3.866907
# 996          0.000000      0.000000
# 997          0.600182      1.000181
# 998          0.367898      0.402289
# 999          1.933397      5.899998
#
#                                     hesitation_periods  number_of_crosses  \
# 980  [0.20021900022402406, 0.09999060025438666, 0.2...            (0, [])
# 981                                                 []            (0, [])
# 982  [0.09983679978176951, 0.8335334998555481, 0.10...            (0, [])
# 983                               [0.1688031000085175]            (0, [])
# 984                                                 []            (0, [])
# 985                                                 []            (0, [])
# 986                                                 []            (0, [])
# 987         [0.33351660007610917, 0.03333899984136224]            (0, [])
# 988          [0.6668742997571826, 0.46682720026001334]            (0, [])
# 989                              [0.03330660006031394]            (0, [])
# 990                               [0.7668679999187589]            (0, [])
# 991                               [0.9358438001945615]            (0, [])
# 992                                                 []            (0, [])
# 993                                                 []            (0, [])
# 994                                                 []            (0, [])
# 995  [0.2668993999250233, 1.100202300120145, 3.8669...            (0, [])
# 996                                                 []            (0, [])
# 997           [1.000181300099939, 0.20018170028924942]            (0, [])
# 998            [0.3335063997656107, 0.402288899756968]            (0, [])
# 999  [0.5001642997376621, 5.8999981000088155, 0.866...            (0, [])
#
#      invalid_cause  sex  age  group
# 980            NaN    F   52     HC
# 981            NaN    F   52     HC
# 982            NaN    F   52     HC
# 983            NaN    F   52     HC
# 984            NaN    F   52     HC
# 985            NaN    F   52     HC
# 986            NaN    F   52     HC
# 987            NaN    F   52     HC
# 988            NaN    F   52     HC
# 989            NaN    F   52     HC
# 990            NaN    F   52     HC
# 991            NaN    F   52     HC
# 992            NaN    F   52     HC
# 993            NaN    F   52     HC
# 994            NaN    F   52     HC
# 995            NaN    F   52     HC
# 996            NaN    F   52     HC
# 997            NaN    F   52     HC
# 998            NaN    F   52     HC
# 999            NaN    F   52     HC
#
# [20 rows x 42 columns]

# %%
for trial in subject.testing_trials:
    print("Trial ID:", trial.id)
    print("Trial Type:", trial.trial_type)
    print("Trial order:", trial.order_of_appearance)
    print("Correct targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['correct_targets_touches'].values[0])
    print("Wrong targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['wrong_targets_touches'].values[0])

    plot_with_color(trial, subject.canvas_size, subject.target_radius)
    plt.show()
# Out:
# Trial ID: 7
# Trial Type: TrialType.PART_A
# Trial order: 2
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 3.0
# Trial ID: 12
# Trial Type: TrialType.PART_B
# Trial order: 3
# Correct targets touches from analysis: 10.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 1
# Trial Type: TrialType.PART_A
# Trial order: 4
# Correct targets touches from analysis: 14.0
# Wrong targets touches from analysis: 8.0
# Trial ID: 20
# Trial Type: TrialType.PART_B
# Trial order: 5
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 3.0
# Trial ID: 11
# Trial Type: TrialType.PART_A
# Trial order: 6
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 3.0
# Trial ID: 13
# Trial Type: TrialType.PART_B
# Trial order: 7
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 2.0
# Trial ID: 17
# Trial Type: TrialType.PART_A
# Trial order: 8
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 3.0
# Trial ID: 0
# Trial Type: TrialType.PART_B
# Trial order: 9
# Correct targets touches from analysis: 14.0
# Wrong targets touches from analysis: 3.0
# Trial ID: 5
# Trial Type: TrialType.PART_A
# Trial order: 10
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 5.0
# Trial ID: 10
# Trial Type: TrialType.PART_B
# Trial order: 11
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 5.0
# Trial ID: 9
# Trial Type: TrialType.PART_A
# Trial order: 12
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 16
# Trial Type: TrialType.PART_B
# Trial order: 13
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 1.0
# Trial ID: 15
# Trial Type: TrialType.PART_A
# Trial order: 14
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 1.0
# Trial ID: 2
# Trial Type: TrialType.PART_B
# Trial order: 15
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 1.0
# Trial ID: 3
# Trial Type: TrialType.PART_A
# Trial order: 16
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 5.0
# Trial ID: 8
# Trial Type: TrialType.PART_B
# Trial order: 17
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 10.0
# Trial ID: 6
# Trial Type: TrialType.PART_A
# Trial order: 18
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 2.0
# Trial ID: 4
# Trial Type: TrialType.PART_B
# Trial order: 19
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 2.0
# Trial ID: 19
# Trial Type: TrialType.PART_A
# Trial order: 20
# Correct targets touches from analysis: 15.0
# Wrong targets touches from analysis: 7.0
# Trial ID: 21
# Trial Type: TrialType.PART_B
# Trial order: 21
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 12.0
