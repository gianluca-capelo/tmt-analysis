# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
print(sys.path[-1])
# Out:
# /home/gus/Documents/REPOS/tmt-analysis/src

# %%
import config
from hand_analysis.runner.run_hand_analysis import run_analysis_with_configuration_parameters

# %%
analysis = run_analysis_with_configuration_parameters(config.DATA_DIR)
experiment = analysis.experiment
# Out:
# 2025-06-05 16:01:39,280 [INFO] root: Processing subject: 0001, group: control
# data_path: /home/gus/Documents/REPOS/tmt-analysis/data/patients_data_pyxations
#
#
# experiment.subjects: [Subject = '0001', Experiment = 'patients_data_pyxations', Subject = '0002', Experiment = 'patients_data_pyxations', Subject = '0003', Experiment = 'patients_data_pyxations', Subject = '0004', Experiment = 'patients_data_pyxations', Subject = '0005', Experiment = 'patients_data_pyxations', Subject = '0006', Experiment = 'patients_data_pyxations', Subject = '0007', Experiment = 'patients_data_pyxations', Subject = '0008', Experiment = 'patients_data_pyxations', Subject = '0009', Experiment = 'patients_data_pyxations', Subject = '0010', Experiment = 'patients_data_pyxations', Subject = '0011', Experiment = 'patients_data_pyxations', Subject = '0012', Experiment = 'patients_data_pyxations', Subject = '0013', Experiment = 'patients_data_pyxations', Subject = '0014', Experiment = 'patients_data_pyxations', Subject = '0015', Experiment = 'patients_data_pyxations', Subject = '0016', Experiment = 'patients_data_pyxations', Subject = '0017', Experiment = 'patients_data_pyxations', Subject = '0018', Experiment = 'patients_data_pyxations', Subject = '0019', Experiment = 'patients_data_pyxations', Subject = '0020', Experiment = 'patients_data_pyxations', Subject = '0021', Experiment = 'patients_data_pyxations', Subject = '0022', Experiment = 'patients_data_pyxations', Subject = '0023', Experiment = 'patients_data_pyxations', Subject = '0024', Experiment = 'patients_data_pyxations', Subject = '0025', Experiment = 'patients_data_pyxations', Subject = '0026', Experiment = 'patients_data_pyxations', Subject = '0027', Experiment = 'patients_data_pyxations', Subject = '0028', Experiment = 'patients_data_pyxations', Subject = '0029', Experiment = 'patients_data_pyxations', Subject = '0030', Experiment = 'patients_data_pyxations', Subject = '0031', Experiment = 'patients_data_pyxations', Subject = '0032', Experiment = 'patients_data_pyxations', Subject = '0033', Experiment = 'patients_data_pyxations', Subject = '0034', Experiment = 'patients_data_pyxations', Subject = '0035', Experiment = 'patients_data_pyxations', Subject = '0036', Experiment = 'patients_data_pyxations', Subject = '0037', Experiment = 'patients_data_pyxations', Subject = '0038', Experiment = 'patients_data_pyxations', Subject = '0039', Experiment = 'patients_data_pyxations', Subject = '0040', Experiment = 'patients_data_pyxations', Subject = '0041', Experiment = 'patients_data_pyxations', Subject = '0042', Experiment = 'patients_data_pyxations', Subject = '0043', Experiment = 'patients_data_pyxations', Subject = '0044', Experiment = 'patients_data_pyxations', Subject = '0045', Experiment = 'patients_data_pyxations', Subject = '0046', Experiment = 'patients_data_pyxations', Subject = '0047', Experiment = 'patients_data_pyxations', Subject = '0048', Experiment = 'patients_data_pyxations', Subject = '0049', Experiment = 'patients_data_pyxations', Subject = '0050', Experiment = 'patients_data_pyxations', Subject = '0051', Experiment = 'patients_data_pyxations', Subject = '0052', Experiment = 'patients_data_pyxations', Subject = '0053', Experiment = 'patients_data_pyxations', Subject = '0054', Experiment = 'patients_data_pyxations', Subject = '0056', Experiment = 'patients_data_pyxations', Subject = '0057', Experiment = 'patients_data_pyxations', Subject = '0058', Experiment = 'patients_data_pyxations', Subject = '0059', Experiment = 'patients_data_pyxations', Subject = '0060', Experiment = 'patients_data_pyxations', Subject = '0061', Experiment = 'patients_data_pyxations', Subject = '0062', Experiment = 'patients_data_pyxations', Subject = '0063', Experiment = 'patients_data_pyxations', Subject = '0064', Experiment = 'patients_data_pyxations', Subject = '0065', Experiment = 'patients_data_pyxations', Subject = '0066', Experiment = 'patients_data_pyxations', Subject = '0067', Experiment = 'patients_data_pyxations', Subject = '0068', Experiment = 'patients_data_pyxations', Subject = '0069', Experiment = 'patients_data_pyxations', Subject = '0070', Experiment = 'pa ...
# 2025-06-05 16:01:39,471 [INFO] root: Processing subject: 0002, group: control
# suj 0001 mapped
# 2025-06-05 16:01:39,692 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:39,699 [INFO] root: Processing subject: 0003, group: MCI
# suj 0002 mapped
# 2025-06-05 16:01:39,925 [INFO] root: Processing subject: 0004, group: MCI
# 2025-06-05 16:01:40,034 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,043 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,052 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,054 [INFO] root: Processing subject: 0005, group: MCI
# suj 0003 mapped
# suj 0004 mapped
# 2025-06-05 16:01:40,169 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,266 [INFO] root: Processing subject: 0006, group: control
# 2025-06-05 16:01:40,392 [INFO] root: Processing subject: 0007, group: control
# suj 0005 mapped
# suj 0006 mapped
# 2025-06-05 16:01:40,622 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,626 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,628 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,637 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:40,643 [INFO] root: Processing subject: 0008, group: MCI
# 2025-06-05 16:01:40,768 [INFO] root: Processing subject: 0009, group: MCI
# suj 0007 mapped
# suj 0008 mapped
# 2025-06-05 16:01:40,900 [INFO] root: Processing subject: 0010, group: control
# suj 0009 mapped
# 2025-06-05 16:01:41,114 [INFO] root: Processing subject: 0011, group: MCI
# 2025-06-05 16:01:41,269 [INFO] root: Processing subject: 0012, group: MCI
# suj 0010 mapped
# suj 0011 mapped
# 2025-06-05 16:01:41,450 [INFO] root: Processing subject: 0013, group: MCI
# suj 0012 mapped
# 2025-06-05 16:01:41,715 [INFO] root: Processing subject: 0014, group: control
# 2025-06-05 16:01:41,831 [INFO] root: Processing subject: 0015, group: MCI
# suj 0013 mapped
# suj 0014 mapped
# 2025-06-05 16:01:42,002 [INFO] root: Processing subject: 0016, group: MCI
# 2025-06-05 16:01:42,132 [INFO] root: Processing subject: 0017, group: MCI
# suj 0015 mapped
# suj 0016 mapped
# 2025-06-05 16:01:42,273 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:42,274 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:42,429 [INFO] root: Processing subject: 0018, group: control
# 2025-06-05 16:01:42,558 [INFO] root: Processing subject: 0019, group: MCI
# suj 0017 mapped
# suj 0018 mapped
# 2025-06-05 16:01:42,717 [INFO] root: Processing subject: 0020, group: MCI
# 2025-06-05 16:01:42,854 [INFO] root: Processing subject: 0021, group: control
# suj 0019 mapped
# suj 0020 mapped
# 2025-06-05 16:01:42,993 [INFO] root: Processing subject: 0022, group: control
# suj 0021 mapped
# 2025-06-05 16:01:43,311 [INFO] root: Processing subject: 0023, group: control
# 2025-06-05 16:01:43,500 [INFO] root: Processing subject: 0024, group: amnesic
# suj 0022 mapped
# suj 0023 mapped
# 2025-06-05 16:01:43,667 [INFO] root: Processing subject: 0025, group: MCI
# suj 0024 mapped
# 2025-06-05 16:01:43,950 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:43,963 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:43,969 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:43,972 [INFO] root: Processing subject: 0026, group: control
# 2025-06-05 16:01:44,109 [INFO] root: Processing subject: 0027, group: MCI
# suj 0025 mapped
# suj 0026 mapped
# 2025-06-05 16:01:44,274 [INFO] root: Processing subject: 0028, group: control
# suj 0027 mapped
# 2025-06-05 16:01:44,629 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:44,630 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:44,634 [INFO] root: Processing subject: 0029, group: control
# suj 0028 mapped
# 2025-06-05 16:01:44,876 [INFO] root: Processing subject: 0030, group: control
# 2025-06-05 16:01:45,066 [INFO] root: Processing subject: 0031, group: control
# suj 0029 mapped
# suj 0030 mapped
# 2025-06-05 16:01:45,239 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:45,248 [INFO] root: Processing subject: 0032, group: control
# 2025-06-05 16:01:45,356 [INFO] root: Processing subject: 0033, group: control
# suj 0031 mapped
# suj 0032 mapped
# 2025-06-05 16:01:45,489 [INFO] root: Processing subject: 0034, group: control
# 2025-06-05 16:01:45,638 [INFO] root: Processing subject: 0035, group: control
# suj 0033 mapped
# suj 0034 mapped
# 2025-06-05 16:01:45,812 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:45,816 [INFO] root: Processing subject: 0036, group: control
# suj 0035 mapped
# 2025-06-05 16:01:46,223 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:46,225 [INFO] root: Processing subject: 0037, group: control
# 2025-06-05 16:01:46,359 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:46,361 [INFO] root: Processing subject: 0038, group: control
# suj 0036 mapped
# suj 0037 mapped
# 2025-06-05 16:01:46,497 [INFO] root: Processing subject: 0039, group: control
# 2025-06-05 16:01:46,640 [INFO] root: Processing subject: 0040, group: control
# suj 0038 mapped
# suj 0039 mapped
# 2025-06-05 16:01:46,801 [INFO] root: Processing subject: 0041, group: control
# 2025-06-05 16:01:46,942 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:46,947 [INFO] root: Processing subject: 0042, group: amnesic
# suj 0040 mapped
# suj 0041 mapped
# 2025-06-05 16:01:47,092 [INFO] root: Processing subject: 0043, group: control
# 2025-06-05 16:01:47,215 [INFO] root: Processing subject: 0044, group: control
# suj 0042 mapped
# suj 0043 mapped
# 2025-06-05 16:01:47,359 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-06-05 16:01:47,515 [INFO] root: Processing subject: 0046, group: MCI
# suj 0044 mapped
# suj 0045 mapped
# 2025-06-05 16:01:47,991 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-06-05 16:01:48,138 [INFO] root: Processing subject: 0048, group: MCI
# suj 0046 mapped
# suj 0047 mapped
# 2025-06-05 16:01:48,331 [INFO] root: Processing subject: 0049, group: MCI
# 2025-06-05 16:01:48,494 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:48,503 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:48,516 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:48,519 [INFO] root: Processing subject: 0050, group: MCI
# suj 0048 mapped
# suj 0049 mapped
# 2025-06-05 16:01:48,657 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:48,664 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:48,679 [INFO] root: Processing subject: 0051, group: MCI
# 2025-06-05 16:01:48,805 [INFO] root: Processing subject: 0052, group: MCI
# suj 0050 mapped
# suj 0051 mapped
# 2025-06-05 16:01:48,979 [INFO] root: Processing subject: 0053, group: MCI
# 2025-06-05 16:01:49,091 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:49,093 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:49,113 [INFO] root: Processing subject: 0054, group: MCI
# suj 0052 mapped
# suj 0053 mapped
# 2025-06-05 16:01:49,280 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:49,284 [INFO] root: Processing subject: 0056, group: control
# 2025-06-05 16:01:49,452 [INFO] root: Processing subject: 0057, group: MCI
# suj 0054 mapped
# suj 0056 mapped
# 2025-06-05 16:01:49,611 [INFO] root: Processing subject: 0058, group: amnesic
# suj 0057 mapped
# 2025-06-05 16:01:50,172 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-06-05 16:01:50,310 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:50,324 [INFO] root: Processing subject: 0060, group: MCI
# suj 0058 mapped
# suj 0059 mapped
# 2025-06-05 16:01:50,493 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-06-05 16:01:50,634 [INFO] root: Processing subject: 0062, group: MCI
# suj 0060 mapped
# suj 0061 mapped
# 2025-06-05 16:01:50,750 [INFO] root: Processing subject: 0063, group: control
# 2025-06-05 16:01:50,885 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:50,886 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:50,888 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:50,889 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:50,892 [INFO] root: Processing subject: 0064, group: MCI
# suj 0062 mapped
# suj 0063 mapped
# 2025-06-05 16:01:51,099 [INFO] root: Processing subject: 0065, group: MCI
# 2025-06-05 16:01:51,252 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,254 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,256 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,261 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,264 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,268 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,271 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,274 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,275 [INFO] root: Processing subject: 0066, group: MCI
# suj 0064 mapped
# suj 0065 mapped
# 2025-06-05 16:01:51,515 [INFO] root: Processing subject: 0067, group: MCI
# 2025-06-05 16:01:51,620 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,624 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,626 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,629 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,632 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,636 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,639 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,643 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:51,646 [INFO] root: Processing subject: 0068, group: MCI
# suj 0066 mapped
# suj 0067 mapped
# 2025-06-05 16:01:51,823 [INFO] root: Processing subject: 0069, group: MCI
# 2025-06-05 16:01:51,950 [INFO] root: Processing subject: 0070, group: control
# suj 0068 mapped
# suj 0069 mapped
# 2025-06-05 16:01:52,106 [INFO] root: Processing subject: 0072, group: MCI
# 2025-06-05 16:01:52,214 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,227 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,229 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,233 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,236 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,239 [INFO] root: Processing subject: 0073, group: MCI
# suj 0070 mapped
# suj 0072 mapped
# 2025-06-05 16:01:52,448 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,926 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:52,929 [INFO] root: Processing subject: 0074, group: control
# 2025-06-05 16:01:53,053 [INFO] root: Processing subject: 0075, group: MCI
# suj 0073 mapped
# suj 0074 mapped
# 2025-06-05 16:01:53,262 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:53,284 [INFO] root: Processing subject: 0076, group: MCI
# 2025-06-05 16:01:53,410 [INFO] root: Processing subject: 0077, group: MCI
# suj 0075 mapped
# suj 0076 mapped
# 2025-06-05 16:01:53,603 [INFO] root: Processing subject: 0078, group: control
# 2025-06-05 16:01:53,771 [INFO] root: Processing subject: 0079, group: control
# suj 0077 mapped
# suj 0078 mapped
# 2025-06-05 16:01:54,030 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-06-05 16:01:54,174 [INFO] root: Processing subject: 0081, group: MCI
# suj 0079 mapped
# suj 0080 mapped
# 2025-06-05 16:01:54,356 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,361 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,368 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,371 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,376 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,379 [INFO] root: Processing subject: 0082, group: MCI
# 2025-06-05 16:01:54,556 [INFO] root: Processing subject: 0083, group: control
# suj 0081 mapped
# suj 0082 mapped
# 2025-06-05 16:01:54,702 [INFO] root: Processing subject: 0084, group: control
# 2025-06-05 16:01:54,856 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:54,876 [INFO] root: Processing subject: 0085, group: control
# suj 0083 mapped
# suj 0084 mapped
# 2025-06-05 16:01:54,998 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,001 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,005 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,007 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,009 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,013 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,021 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:55,030 [INFO] root: Processing subject: 0086, group: control
# 2025-06-05 16:01:55,178 [INFO] root: Processing subject: 0087, group: control
# suj 0085 mapped
# suj 0086 mapped
# 2025-06-05 16:01:55,353 [INFO] root: Processing subject: 0088, group: MCI
# suj 0087 mapped
# 2025-06-05 16:01:55,570 [INFO] root: Processing subject: 0089, group: control
# 2025-06-05 16:01:55,721 [INFO] root: Processing subject: 0090, group: control
# suj 0088 mapped
# suj 0089 mapped
# 2025-06-05 16:01:55,861 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:56,570 [INFO] root: Processing subject: 0091, group: control
# 2025-06-05 16:01:56,723 [INFO] root: Processing subject: 0092, group: MCI
# suj 0090 mapped
# suj 0091 mapped
# 2025-06-05 16:01:56,913 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:56,921 [INFO] root: Processing subject: 0093, group: MCI
# 2025-06-05 16:01:57,095 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:57,099 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:57,100 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:57,107 [INFO] root: Processing subject: 0094, group: MCI
# suj 0092 mapped
# suj 0093 mapped
# 2025-06-05 16:01:57,279 [INFO] root: Processing subject: 0095, group: control
# 2025-06-05 16:01:57,450 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:57,457 [INFO] root: Processing subject: 0096, group: MCI
# suj 0094 mapped
# suj 0095 mapped
# 2025-06-05 16:01:57,608 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:57,610 [INFO] root: Processing subject: 0097, group: MCI
# 2025-06-05 16:01:57,733 [INFO] root: Processing subject: 0098, group: MCI
# suj 0096 mapped
# suj 0097 mapped
# 2025-06-05 16:01:57,908 [INFO] root: Processing subject: 0099, group: MCI
# 2025-06-05 16:01:58,107 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:58,108 [INFO] root: Processing subject: 0100, group: control
# suj 0098 mapped
# suj 0099 mapped
# 2025-06-05 16:01:58,261 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:58,265 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:58,278 [WARNING] root: No target was hit in the cursor trail.
# 2025-06-05 16:01:58,282 [INFO] root: Processing subject: 0101, group: control
# 2025-06-05 16:01:58,473 [INFO] root: Experiment loaded. Number of subjects: 99
# suj 0100 mapped
# suj 0101 mapped
# 2025-06-05 16:01:58,654 [ERROR] root: Cut trial error for trial 0 of subject 0001: Trial 0 of subject 0001 has 4 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 0 of subject 0001 has 4 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:58,839 [ERROR] root: Cut trial error for trial 12 of subject 0001: Trial 12 of subject 0001 has 5 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 12 of subject 0001 has 5 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:58,962 [ERROR] root: Cut trial error for trial 8 of subject 0002: Trial 8 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 8 has less than 8 correct targets.
# 2025-06-05 16:01:58,984 [ERROR] root: Cut trial error for trial 15 of subject 0002: Trial 15 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-06-05 16:01:59,081 [ERROR] root: Cut trial error for trial 21 of subject 0002: Trial 21 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 21 has less than 8 correct targets.
# 2025-06-05 16:01:59,084 [ERROR] root: Cut trial error for trial 20 of subject 0002: Trial 20 of subject 0002 has 4 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 20 of subject 0002 has 4 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,084 [WARNING] root: Trial 1 of subject 0002 is not valid from the mapper.
# 2025-06-05 16:01:59,088 [ERROR] root: Cut trial error for trial 12 of subject 0002: Trial 12 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 12 has less than 8 correct targets.
# 2025-06-05 16:01:59,091 [ERROR] root: Cut trial error for trial 6 of subject 0002: Trial 6 of subject 0002 has 7 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 6 of subject 0002 has 7 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,276 [ERROR] root: Cut trial error for trial 9 of subject 0003: Trial 9 of subject 0003 has 5 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 9 of subject 0003 has 5 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,478 [ERROR] root: Cut trial error for trial 19 of subject 0004: Trial 19 of subject 0004 has 6 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 19 of subject 0004 has 6 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,481 [ERROR] root: Cut trial error for trial 15 of subject 0004: Trial 15 of subject 0004 has 6 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 15 of subject 0004 has 6 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,483 [ERROR] root: Cut trial error for trial 0 of subject 0004: Trial 0 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 0 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,485 [ERROR] root: Cut trial error for trial 2 of subject 0004: Trial 2 of subject 0004 has 3 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 2 of subject 0004 has 3 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,487 [ERROR] root: Cut trial error for trial 9 of subject 0004: Trial 9 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 9 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,491 [ERROR] root: Cut trial error for trial 10 of subject 0004: Trial 10 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 10 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,495 [ERROR] root: Cut trial error for trial 1 of subject 0004: Trial 1 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 1 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,498 [ERROR] root: Cut trial error for trial 13 of subject 0004: Trial 13 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 13 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,498 [WARNING] root: Trial 7 of subject 0004 is not valid from the mapper.
# 2025-06-05 16:01:59,500 [ERROR] root: Cut trial error for trial 17 of subject 0004: Trial 17 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 17 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,502 [ERROR] root: Cut trial error for trial 16 of subject 0004: Trial 16 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 16 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,505 [ERROR] root: Cut trial error for trial 12 of subject 0004: Trial 12 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 12 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,508 [ERROR] root: Cut trial error for trial 6 of subject 0004: Trial 6 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 6 of subject 0004 has 4 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,533 [ERROR] root: Cut trial error for trial 21 of subject 0004: Trial 21 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 21 of subject 0004 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,536 [ERROR] root: Cut trial error for trial 5 of subject 0004: Trial 5 of subject 0004 has 5 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 5 of subject 0004 has 5 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,538 [ERROR] root: Cut trial error for trial 11 of subject 0004: Trial 11 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 11 of subject 0004 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,538 [WARNING] root: Trial 3 of subject 0004 is not valid from the mapper.
# 2025-06-05 16:01:59,540 [ERROR] root: Cut trial error for trial 8 of subject 0004: Trial 8 of subject 0004 has 5 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 8 of subject 0004 has 5 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,567 [WARNING] root: Trial 2 of subject 0005 is not valid from the mapper.
# 2025-06-05 16:01:59,571 [ERROR] root: Cut trial error for trial 8 of subject 0005: Trial 8 of subject 0005 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 8 of subject 0005 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:01:59,576 [ERROR] root: Cut trial error for trial 16 of subject 0005: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
# ...
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 11 of subject 0100 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,786 [ERROR] root: Cut trial error for trial 1 of subject 0100: Trial 1 of subject 0100 has 6 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 1 of subject 0100 has 6 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,787 [WARNING] root: Trial 3 of subject 0100 is not valid from the mapper.
# 2025-06-05 16:02:30,815 [ERROR] root: Cut trial error for trial 10 of subject 0100: Trial 10 of subject 0100 has 3 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 10 of subject 0100 has 3 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,860 [ERROR] root: Cut trial error for trial 15 of subject 0100: Trial 15 of subject 0100 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 15 of subject 0100 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,890 [ERROR] root: Cut trial error for trial 9 of subject 0100: Trial 9 of subject 0100 has 3 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 9 of subject 0100 has 3 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,900 [ERROR] root: Cut trial error for trial 4 of subject 0100: Trial 4 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 4 has less than 8 correct targets.
# 2025-06-05 16:02:30,906 [ERROR] root: Cut trial error for trial 6 of subject 0100: Trial 6 of subject 0100 has 2 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 6 of subject 0100 has 2 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,945 [ERROR] root: Cut trial error for trial 19 of subject 0100: Trial 19 of subject 0100 has 7 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 19 of subject 0100 has 7 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,948 [ERROR] root: Cut trial error for trial 20 of subject 0100: Trial 20 of subject 0100 has 5 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 20 of subject 0100 has 5 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:30,988 [WARNING] root: Trial 17 of subject 0100 is not valid from the mapper.
# 2025-06-05 16:02:31,013 [ERROR] root: Cut trial error for trial 13 of subject 0100: Trial 13 of subject 0100 has 1 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 13 of subject 0100 has 1 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:31,111 [ERROR] root: Cut trial error for trial 6 of subject 0101: Trial 6 of subject 0101 has 7 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 6 of subject 0101 has 7 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:31,270 [ERROR] root: Cut trial error for trial 20 of subject 0101: Trial 20 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 69, in cut_trial_at_minimum_targets
#     return cut_trial_at_minimum_correct_targets(trial, correct_targets_minimum, subject.target_radius)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 94, in cut_trial_at_minimum_correct_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 20 has less than 8 correct targets.
# 2025-06-05 16:02:31,361 [ERROR] root: Cut trial error for trial 21 of subject 0101: Trial 21 of subject 0101 has 3 correct target touches, but the minimum required is 8.
# Traceback (most recent call last):
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 201, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 34, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gus/Documents/REPOS/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 65, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} of subject {subject_id} has {correct_targets_touches} correct target touches, "
# ValueError: Trial 21 of subject 0101 has 3 correct target touches, but the minimum required is 8.
# 2025-06-05 16:02:31,531 [INFO] root: Metrics successfully saved to /home/gus/Documents/REPOS/tmt-analysis/data/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  non_cut_zigzag_amplitude  \
# 0                          2         0.249557                       NaN
# 1                          3         0.249557                 -1.172266
# 2                          4         0.249557                       NaN
# 3                          5         0.249557                 -1.611113
# 4                          6         0.249557                       NaN
#
#    non_cut_total_distance  ...  max_duration  \
# 0                3.724429  ...      4.333857
# 1                3.451943  ...      0.766811
# 2                3.498912  ...      0.366989
# 3                3.330454  ...      0.164361
# 4                3.852083  ...      0.066742
#
#                            hesitation_periods  correct_targets_touches  \
# 0     [4.333857099999932, 0.2668112999999721]                      8.0
# 1   [0.7668111000000408, 0.06664189999992232]                      8.0
# 2   [0.3669890999999552, 0.06666559999985111]                      8.0
# 3  [0.06663750000006985, 0.16436069999986103]                      8.0
# 4                        [0.0667415999998866]                      8.0
#
#    wrong_targets_touches  number_of_crosses  distance_difference_from_ideal  \
# 0                    0.0                NaN                        0.026317
# 1                    0.0                NaN                        0.049065
# 2                    0.0                NaN                        0.016579
# 3                    0.0                NaN                        0.021309
# 4                    0.0                NaN                        0.017064
#
#    area_difference_from_ideal  intra_target_time  inter_target_time  \
# 0                    0.004466           1.464958           0.197898
# 1                    0.001413           1.147711           0.199746
# 2                    0.003162           0.952390           0.199828
# 3                    0.003553           1.161951           0.199647
# 4                    0.001149           1.276216           0.199847
#
#    invalid_cause
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 83 columns]
# Len of subjects: 99

# %%
subject = experiment.subjects["0063"]
subject
# Out:
# TMTSubject(training_trials=[], testing_trials=[TMTTrial(stimuli=[TMTTarget(content='1', position=Coordinate(x=-0.20191733333333317, y=-0.2820346666666667)), TMTTarget(content='2', position=Coordinate(x=-0.1183973333333332, y=-0.3655546666666667)), TMTTarget(content='3', position=Coordinate(x=-0.14623733333333336, y=-0.1706746666666666)), TMTTarget(content='4', position=Coordinate(x=-0.25759733333333334, y=-0.11499466666666662)), TMTTarget(content='5', position=Coordinate(x=-0.007037333333333234, y=-0.1706746666666666)), TMTTarget(content='6', position=Coordinate(x=0.16000266666666654, y=-0.11499466666666662)), TMTTarget(content='7', position=Coordinate(x=0.2435226666666667, y=0.13556533333333332)), TMTTarget(content='8', position=Coordinate(x=0.38272266666666666, y=0.24692533333333327)), TMTTarget(content='9', position=Coordinate(x=0.2713626666666667, y=-0.059314666666666634)), TMTTarget(content='10', position=Coordinate(x=0.41056266666666663, y=0.1634053333333333)), TMTTarget(content='11', position=Coordinate(x=0.46624266666666664, y=0.24692533333333327)), TMTTarget(content='12', position=Coordinate(x=0.2713626666666667, y=0.3861253333333332)), TMTTarget(content='13', position=Coordinate(x=0.020802666666666757, y=0.1912453333333333)), TMTTarget(content='14', position=Coordinate(x=-0.20191733333333317, y=0.35828533333333323)), TMTTarget(content='15', position=Coordinate(x=-0.20191733333333317, y=0.07988533333333332))], cursor_trail=[CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.00022189971059560776), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.034353899769485), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.06736549967899919), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.10070719989016652), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.13400590000674129), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.16745579987764359), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.20068900007754564), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.23400990013033152), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.2673951000906527), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.284003600012511), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.3173465998843312), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.3340190998278558), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.3673618999309838), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.38398269983008504), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.4173531997948885), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.4506454998627305), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.4840488997288048), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.5173535998910666), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.5340304998680949), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.5673638000153005), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.6007010000757873), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.6340193999931216), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.6673591998405755), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.7006692998111248), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.7340167998336256), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.7673665997572243), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.7840084000490606), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.817372600082308), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.8339825998991728), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.8673475999385118), CursorInfo(position=Coordinate(x=-0.0037037036, y=0.0), time=0.900658799801 ...

# %%
from neurotask.tmt.metrics.speed_metrics import calculate_speeds_between_cursor_positions, \
    calculate_accelerations_between_cursor_positions
from matplotlib import pyplot as plt
from neurotask.tmt.model.tmt_model import TMTTrial


def plot_with_color(trial: TMTTrial, canvas_size: int, target_radius: float, color_by='time'):
    """
    Plotea la trayectoria del cursor junto con los targets en un gráfico,
    ajustando el tamaño del gráfico al tamaño del canvas y dibujando círculos
    alrededor de los targets con su contenido. La trayectoria del cursor se
    dibuja con puntos cuyos colores cambian en función del tiempo, la velocidad o la aceleración.
    El primer clic en el target se destaca con un marcador especial.

    Parameters:
    - trial: TMTTrial, el trial con la trayectoria del cursor y los targets.
    - canvas_size: int, tamaño del canvas (ancho y alto).
    - target_radius: float, radio de los círculos que rodean los targets.
    - color_by: str, 'time', 'speed' o 'acceleration', determina si el color de los puntos cambia en función del tiempo, velocidad o aceleración.
    """

    # Extraer la posición de los targets
    target_x = [target.position.x for target in trial.stimuli]
    target_y = [target.position.y for target in trial.stimuli]
    target_contents = [target.content for target in trial.stimuli]

    cursor_trail_from_first_click = trial.get_cursor_trail_from_start()
    # Extraer la trayectoria del cursor
    cursor_x = [cursor_info.position.x for cursor_info in cursor_trail_from_first_click]
    cursor_y = [cursor_info.position.y for cursor_info in cursor_trail_from_first_click]
    cursor_times = [cursor_info.time for cursor_info in cursor_trail_from_first_click]

    if color_by == 'time':
        # Normalizar tiempos para que estén en el rango [0, 1]
        norm = plt.Normalize(min(cursor_times), max(cursor_times))
        colors = plt.cm.viridis(norm(cursor_times))  # Usar un mapa de colores para el tiempo
    elif color_by == 'speed':
        speeds = calculate_speeds_between_cursor_positions(trial)
        speeds = [0] + speeds  # Para igualar el número de puntos con las velocidades calculadas
        norm = plt.Normalize(min(speeds), max(speeds))
        colors = plt.cm.viridis(norm(speeds))  # Usar un mapa de colores para la velocidad
    elif color_by == 'acceleration':
        accelerations = calculate_accelerations_between_cursor_positions(trial)
        accelerations = [0, 0] + accelerations  # Igualar el número de puntos (2 primeros puntos sin aceleración)
        norm = plt.Normalize(min(accelerations), max(accelerations))
        colors = plt.cm.viridis(norm(accelerations))  # Usar un mapa de colores para la aceleración
    else:
        raise ValueError("El parámetro color_by debe ser 'time', 'speed' o 'acceleration'.")

    # Crear el gráfico
    fig, ax = plt.subplots(figsize=(8, 8))

    # Dibujar la trayectoria del cursor como líneas coloreadas por tiempo o velocidad
    for i in range(len(cursor_x) - 1):
        plt.plot([cursor_x[i], cursor_x[i + 1]],
                 [cursor_y[i], cursor_y[i + 1]],
                 color=colors[i], linewidth=2, zorder=4)

    # Dibujar los targets como círculos con el contenido dentro
    for x, y, content in zip(target_x, target_y, target_contents):
        circle = plt.Circle((x, y), target_radius, color='red', alpha=0.3, zorder=5)
        plt.gca().add_patch(circle)
        # Añadir el contenido del target en el centro del círculo
        plt.text(x, y, content, color='black', fontsize=8, ha='center', va='center', zorder=6)

    # Destacar el primer clic
    if trial.start:
        fc_x = trial.start.position.x
        fc_y = trial.start.position.y
        plt.scatter(fc_x, fc_y, color='cyan', edgecolor='black', s=100, label='First Click', zorder=7,
                    marker='o', alpha=0.3)

    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar_label = 'Time' if color_by == 'time' else 'Speed' if color_by == 'speed' else 'Acceleration'
    cbar = fig.colorbar(sm, ax=ax, label=cbar_label)

    # # Set plot limits based on canvas size
    # ax.set_xlim(-canvas_size, canvas_size)
    # ax.set_ylim(canvas_size, -canvas_size,)  # Inverted Y-axis if needed

    # Add labels and title
    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.set_title('Cursor Trail with Targets')

    # Ensure equal aspect ratio
    ax.set_aspect('equal', adjustable='box')

    # Add legend
    ax.legend()

    return fig

# %%
from hand_analysis.loader.load_last_split import load_last_analysis
train_set, _ = load_last_analysis()
subject_analysis = train_set[train_set['subject_id'] == 63]
subject_analysis
# Out:
# 2025-06-05 16:14:24,635 [INFO] root: Loading split from /home/gus/Documents/REPOS/tmt-analysis/data/hand_analysis/2025-05-30_20-39-12
#       subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 1140          63         7     PART_A      True                          2
# 1141          63         1     PART_B      True                          3
# 1142          63        10     PART_A     False                          4
# 1143          63         3     PART_B     False                          5
# 1144          63        20     PART_A      True                          6
# 1145          63         2     PART_B     False                          7
# 1146          63        12     PART_A     False                          8
# 1147          63        16     PART_B     False                          9
# 1148          63        21     PART_A      True                         10
# 1149          63         8     PART_B      True                         11
# 1150          63        13     PART_A     False                         12
# 1151          63         0     PART_B     False                         13
# 1152          63        11     PART_A     False                         14
# 1153          63        15     PART_B     False                         15
# 1154          63        19     PART_A     False                         16
# 1155          63        17     PART_B      True                         17
# 1156          63         5     PART_A     False                         18
# 1157          63         4     PART_B      True                         19
# 1158          63         9     PART_A     False                         20
# 1159          63         6     PART_B      True                         21
#
#       speed_threshold  non_cut_zigzag_amplitude  non_cut_total_distance  \
# 1140         0.296781                       NaN                3.433824
# 1141         0.296781                 -2.533412                4.595471
# 1142         0.296781                       NaN                     NaN
# 1143         0.296781                       NaN                     NaN
# 1144         0.296781                       NaN                3.718462
# 1145         0.296781                       NaN                     NaN
# 1146         0.296781                       NaN                     NaN
# 1147         0.296781                       NaN                     NaN
# 1148         0.296781                       NaN                3.649650
# 1149         0.296781                 -0.959974                3.645169
# 1150         0.296781                       NaN                     NaN
# 1151         0.296781                       NaN                     NaN
# 1152         0.296781                       NaN                     NaN
# 1153         0.296781                       NaN                     NaN
# 1154         0.296781                       NaN                     NaN
# 1155         0.296781                 -0.949896                3.454970
# 1156         0.296781                       NaN                     NaN
# 1157         0.296781                 -0.688884                4.621715
# 1158         0.296781                       NaN                     NaN
# 1159         0.296781                 -0.900063                4.061750
#
#       non_cut_rt  non_cut_mean_speed  ...  wrong_targets_touches  \
# 1140     11034.0            0.367411  ...                    0.0
# 1141     21667.0            0.211771  ...                    0.0
# 1142         NaN                 NaN  ...                    NaN
# 1143         NaN                 NaN  ...                    NaN
# 1144     13964.0            0.330831  ...                    0.0
# 1145         NaN                 NaN  ...                    NaN
# 1146         NaN                 NaN  ...                    NaN
# 1147         NaN                 NaN  ...                    NaN
# 1148     10610.0            0.414398  ...                    0.0
# 1149     14271.0            0.290471  ...                    0.0
# 1150         NaN                 NaN  ...                    NaN
# 1151         NaN                 NaN  ...                    NaN
# 1152         NaN                 NaN  ...                    NaN
# 1153         NaN                 NaN  ...                    NaN
# 1154         NaN                 NaN  ...                    NaN
# 1155     14751.0            0.271910  ...                    0.0
# 1156         NaN                 NaN  ...                    NaN
# 1157     16738.0            0.318031  ...                    0.0
# 1158         NaN                 NaN  ...                    NaN
# 1159     14048.0            0.330765  ...                    0.0
#
#       number_of_crosses  distance_difference_from_ideal  \
# 1140                NaN                        0.016598
# 1141                NaN                        0.040269
# 1142                NaN                             NaN
# 1143                NaN                             NaN
# 1144                NaN                        0.053425
# 1145                NaN                             NaN
# 1146                NaN                             NaN
# 1147                NaN                             NaN
# 1148                NaN                        0.044959
# 1149                NaN                        0.026903
# 1150                NaN                             NaN
# 1151                NaN                             NaN
# 1152                NaN                             NaN
# 1153                NaN                             NaN
# 1154                NaN                             NaN
# 1155                NaN                        0.019577
# 1156                NaN                             NaN
# 1157                NaN                        0.038379
# 1158                NaN                             NaN
# 1159                NaN                        0.066872
#
#       area_difference_from_ideal  intra_target_time  inter_target_time  \
# 1140                    0.002021           0.638451           0.197732
# 1141                    0.001428           2.091217           0.195295
# 1142                         NaN                NaN                NaN
# 1143                         NaN                NaN                NaN
# 1144                    0.010156           0.924194           0.197348
# 1145                         NaN                NaN                NaN
# 1146                         NaN                NaN                NaN
# 1147                         NaN                NaN                NaN
# 1148                    0.007149           0.661976           0.199727
# 1149                    0.004112           0.938481           0.197361
# 1150                         NaN                NaN                NaN
# 1151                         NaN                NaN                NaN
# 1152                         NaN                NaN                NaN
# 1153                         NaN                NaN                NaN
# 1154                         NaN                NaN                NaN
# 1155                    0.003227           0.776562           0.197479
# 1156                         NaN                NaN                NaN
# 1157                    0.010045           0.861958           0.199643
# 1158                         NaN                NaN                NaN
# 1159                    0.009288           1.076260           0.199599
#
#                     invalid_cause  sex  age  group
# 1140                          NaN    F   52     HC
# 1141                          NaN    F   52     HC
# 1142           CUT_CRITERIA_ERROR    F   52     HC
# 1143           CUT_CRITERIA_ERROR    F   52     HC
# 1144                          NaN    F   52     HC
# 1145           CUT_CRITERIA_ERROR    F   52     HC
# 1146           CUT_CRITERIA_ERROR    F   52     HC
# 1147           CUT_CRITERIA_ERROR    F   52     HC
# 1148                          NaN    F   52     HC
# 1149                          NaN    F   52     HC
# 1150           CUT_CRITERIA_ERROR    F   52     HC
# 1151  INVALID_START_CONFIGURATION    F   52     HC
# 1152  INVALID_START_CONFIGURATION    F   52     HC
# 1153  INVALID_START_CONFIGURATION    F   52     HC
# 1154  INVALID_START_CONFIGURATION    F   52     HC
# 1155                          NaN    F   52     HC
# 1156           CUT_CRITERIA_ERROR    F   52     HC
# 1157                          NaN    F   52     HC
# 1158           CUT_CRITERIA_ERROR    F   52     HC
# 1159                          NaN    F   52     HC
#
# [20 rows x 84 columns]

# %%
for trial in subject.testing_trials:
    print("Trial ID:", trial.id)
    print("Trial Type:", trial.trial_type)
    print("Trial order:", trial.order_of_appearance)
    print("Correct targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['correct_targets_touches'].values[0])
    print("Wrong targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['wrong_targets_touches'].values[0])

    plot_with_color(trial, subject.canvas_size, subject.target_radius)
    plt.show()
# Out:
# Trial ID: 7
# Trial Type: TrialType.PART_A
# Trial order: 2
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 1
# Trial Type: TrialType.PART_B
# Trial order: 3
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 10
# Trial Type: TrialType.PART_A
# Trial order: 4
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 3
# Trial Type: TrialType.PART_B
# Trial order: 5
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 20
# Trial Type: TrialType.PART_A
# Trial order: 6
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 2
# Trial Type: TrialType.PART_B
# Trial order: 7
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 12
# Trial Type: TrialType.PART_A
# Trial order: 8
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 16
# Trial Type: TrialType.PART_B
# Trial order: 9
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 21
# Trial Type: TrialType.PART_A
# Trial order: 10
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 8
# Trial Type: TrialType.PART_B
# Trial order: 11
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 0.0
# Trial ID: 13
# Trial Type: TrialType.PART_A
# Trial order: 12
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# Trial ID: 0
# Trial Type: TrialType.PART_B
# Trial order: 13
# Correct targets touches from analysis: nan
# Wrong targets touches from analysis: nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 8
#       5 print("Correct targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['correct_targets_touches'].values[0])
#       6 print("Wrong targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['wrong_targets_touches'].values[0])
# ----> 8 plot_with_color(trial, subject.canvas_size, subject.target_radius)
#       9 plt.show()
#
# Cell In[10], line 27, in plot_with_color(trial, canvas_size, target_radius, color_by)
#      24 target_y = [target.position.y for target in trial.stimuli]
#      25 target_contents = [target.content for target in trial.stimuli]
# ---> 27 cursor_trail_from_first_click = trial.get_cursor_trail_from_start()
#      28 # Extraer la trayectoria del cursor
#      29 cursor_x = [cursor_info.position.x for cursor_info in cursor_trail_from_first_click]
#
# File ~/Documents/REPOS/neurotask/neurotask/neurotask/tmt/model/tmt_model.py:60, in TMTTrial.get_cursor_trail_from_start(self)
#      57     return self.cursor_trail
#      59 if self.start is None:
# ---> 60     raise ValueError("first_click_cursor_info no está definido en este trial.")
#      62 start_time = self.start.time
#      64 filtered_cursor_trail = [cursor_info for cursor_info in self.cursor_trail
#      65                          if cursor_info.time >= start_time]
#
# ValueError: first_click_cursor_info no está definido en este trial.
