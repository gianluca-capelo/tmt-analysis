# %%
from src import config
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_configuration_parameters

analysis = run_analysis_with_configuration_parameters(config.DATA_DIR)
experiment = analysis.experiment
# Out:
# 2025-05-11 22:52:13,337 [INFO] root: Processing subject: 0001, group: control
# 2025-05-11 22:52:13,543 [INFO] root: Processing subject: 0002, group: control
# 2025-05-11 22:52:13,745 [INFO] root: Processing subject: 0003, group: MCI
# 2025-05-11 22:52:13,886 [INFO] root: Processing subject: 0004, group: MCI
# 2025-05-11 22:52:14,097 [INFO] root: Processing subject: 0005, group: MCI
# 2025-05-11 22:52:14,314 [INFO] root: Processing subject: 0006, group: control
# 2025-05-11 22:52:14,439 [INFO] root: Processing subject: 0007, group: control
# 2025-05-11 22:52:14,574 [INFO] root: Processing subject: 0008, group: MCI
# 2025-05-11 22:52:14,794 [INFO] root: Processing subject: 0009, group: MCI
# 2025-05-11 22:52:14,922 [INFO] root: Processing subject: 0010, group: control
# 2025-05-11 22:52:15,036 [INFO] root: Processing subject: 0011, group: MCI
# 2025-05-11 22:52:15,302 [INFO] root: Processing subject: 0012, group: MCI
# 2025-05-11 22:52:15,455 [INFO] root: Processing subject: 0013, group: MCI
# 2025-05-11 22:52:15,588 [INFO] root: Processing subject: 0014, group: control
# 2025-05-11 22:52:15,858 [INFO] root: Processing subject: 0015, group: MCI
# 2025-05-11 22:52:16,011 [INFO] root: Processing subject: 0016, group: MCI
# 2025-05-11 22:52:16,132 [INFO] root: Processing subject: 0017, group: MCI
# 2025-05-11 22:52:16,279 [INFO] root: Processing subject: 0018, group: control
# 2025-05-11 22:52:16,572 [INFO] root: Processing subject: 0019, group: MCI
# 2025-05-11 22:52:16,714 [INFO] root: Processing subject: 0020, group: MCI
# 2025-05-11 22:52:16,855 [INFO] root: Processing subject: 0021, group: control
# 2025-05-11 22:52:16,991 [INFO] root: Processing subject: 0022, group: control
# 2025-05-11 22:52:17,129 [INFO] root: Processing subject: 0023, group: control
# 2025-05-11 22:52:17,468 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-05-11 22:52:17,604 [INFO] root: Processing subject: 0025, group: MCI
# 2025-05-11 22:52:17,772 [INFO] root: Processing subject: 0026, group: control
# 2025-05-11 22:52:17,893 [INFO] root: Processing subject: 0027, group: MCI
# 2025-05-11 22:52:18,046 [INFO] root: Processing subject: 0028, group: control
# 2025-05-11 22:52:18,199 [INFO] root: Processing subject: 0029, group: control
# 2025-05-11 22:52:18,607 [INFO] root: Processing subject: 0030, group: control
# 2025-05-11 22:52:18,745 [INFO] root: Processing subject: 0031, group: control
# 2025-05-11 22:52:18,899 [INFO] root: Processing subject: 0032, group: control
# 2025-05-11 22:52:19,011 [INFO] root: Processing subject: 0033, group: control
# 2025-05-11 22:52:19,151 [INFO] root: Processing subject: 0034, group: control
# 2025-05-11 22:52:19,281 [INFO] root: Processing subject: 0035, group: control
# 2025-05-11 22:52:19,411 [INFO] root: Processing subject: 0036, group: control
# 2025-05-11 22:52:19,534 [INFO] root: Processing subject: 0037, group: control
# 2025-05-11 22:52:19,959 [INFO] root: Processing subject: 0038, group: control
# 2025-05-11 22:52:20,091 [INFO] root: Processing subject: 0039, group: control
# 2025-05-11 22:52:20,218 [INFO] root: Processing subject: 0040, group: control
# 2025-05-11 22:52:20,361 [INFO] root: Processing subject: 0041, group: control
# 2025-05-11 22:52:20,484 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-05-11 22:52:20,631 [INFO] root: Processing subject: 0043, group: control
# 2025-05-11 22:52:20,759 [INFO] root: Processing subject: 0044, group: control
# 2025-05-11 22:52:20,887 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-05-11 22:52:21,023 [INFO] root: Processing subject: 0046, group: MCI
# 2025-05-11 22:52:21,536 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-05-11 22:52:21,673 [INFO] root: Processing subject: 0048, group: MCI
# 2025-05-11 22:52:21,816 [INFO] root: Processing subject: 0049, group: MCI
# 2025-05-11 22:52:21,972 [INFO] root: Processing subject: 0050, group: MCI
# 2025-05-11 22:52:22,078 [WARNING] root: No target was hit in the cursor trail.
# 2025-05-11 22:52:22,107 [INFO] root: Processing subject: 0051, group: MCI
# 2025-05-11 22:52:22,229 [INFO] root: Processing subject: 0052, group: MCI
# 2025-05-11 22:52:22,379 [INFO] root: Processing subject: 0053, group: MCI
# 2025-05-11 22:52:22,472 [WARNING] root: No target was hit in the cursor trail.
# 2025-05-11 22:52:22,474 [WARNING] root: No target was hit in the cursor trail.
# 2025-05-11 22:52:22,497 [INFO] root: Processing subject: 0054, group: MCI
# 2025-05-11 22:52:22,645 [INFO] root: Processing subject: 0055, group: MCI
# 2025-05-11 22:52:22,763 [INFO] root: Processing subject: 0056, group: control
# 2025-05-11 22:52:22,899 [INFO] root: Processing subject: 0057, group: MCI
# 2025-05-11 22:52:23,537 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-05-11 22:52:23,710 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-05-11 22:52:23,872 [INFO] root: Processing subject: 0060, group: MCI
# 2025-05-11 22:52:24,037 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-05-11 22:52:24,182 [INFO] root: Processing subject: 0062, group: MCI
# 2025-05-11 22:52:24,294 [INFO] root: Processing subject: 0063, group: control
# 2025-05-11 22:52:24,413 [INFO] root: Processing subject: 0064, group: MCI
# 2025-05-11 22:52:24,560 [INFO] root: Processing subject: 0065, group: MCI
# 2025-05-11 22:52:24,708 [INFO] root: Processing subject: 0066, group: MCI
# 2025-05-11 22:52:24,874 [INFO] root: Processing subject: 0067, group: MCI
# 2025-05-11 22:52:25,000 [INFO] root: Processing subject: 0068, group: MCI
# 2025-05-11 22:52:25,141 [INFO] root: Processing subject: 0069, group: MCI
# 2025-05-11 22:52:25,258 [INFO] root: Processing subject: 0070, group: control
# 2025-05-11 22:52:25,389 [INFO] root: Processing subject: 0071, group: control
# 2025-05-11 22:52:26,063 [INFO] root: Processing subject: 0072, group: MCI
# 2025-05-11 22:52:26,190 [INFO] root: Processing subject: 0073, group: MCI
# 2025-05-11 22:52:26,353 [INFO] root: Processing subject: 0074, group: control
# 2025-05-11 22:52:26,483 [INFO] root: Processing subject: 0075, group: MCI
# 2025-05-11 22:52:26,641 [INFO] root: Processing subject: 0076, group: MCI
# 2025-05-11 22:52:26,767 [INFO] root: Processing subject: 0077, group: MCI
# 2025-05-11 22:52:26,912 [INFO] root: Processing subject: 0078, group: control
# 2025-05-11 22:52:27,062 [INFO] root: Processing subject: 0079, group: control
# 2025-05-11 22:52:27,232 [WARNING] root: No target was hit in the cursor trail.
# 2025-05-11 22:52:27,250 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-05-11 22:52:27,386 [INFO] root: Processing subject: 0081, group: MCI
# 2025-05-11 22:52:27,513 [INFO] root: Processing subject: 0082, group: MCI
# 2025-05-11 22:52:27,650 [INFO] root: Processing subject: 0083, group: control
# 2025-05-11 22:52:27,779 [INFO] root: Processing subject: 0084, group: control
# 2025-05-11 22:52:27,923 [INFO] root: Processing subject: 0085, group: control
# 2025-05-11 22:52:28,049 [INFO] root: Processing subject: 0086, group: control
# 2025-05-11 22:52:28,184 [INFO] root: Processing subject: 0087, group: control
# 2025-05-11 22:52:28,298 [INFO] root: Processing subject: 0088, group: MCI
# 2025-05-11 22:52:29,093 [INFO] root: Processing subject: 0089, group: control
# 2025-05-11 22:52:29,235 [INFO] root: Processing subject: 0090, group: control
# 2025-05-11 22:52:29,365 [INFO] root: Processing subject: 0091, group: control
# 2025-05-11 22:52:29,482 [INFO] root: Processing subject: 0092, group: MCI
# 2025-05-11 22:52:29,621 [INFO] root: Processing subject: 0093, group: MCI
# 2025-05-11 22:52:29,759 [INFO] root: Processing subject: 0094, group: MCI
# 2025-05-11 22:52:29,900 [INFO] root: Processing subject: 0095, group: control
# 2025-05-11 22:52:30,029 [INFO] root: Processing subject: 0096, group: MCI
# 2025-05-11 22:52:30,160 [INFO] root: Processing subject: 0097, group: MCI
# 2025-05-11 22:52:30,284 [INFO] root: Processing subject: 0098, group: MCI
# 2025-05-11 22:52:30,415 [INFO] root: Processing subject: 0099, group: MCI
# 2025-05-11 22:52:30,544 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-05-11 22:52:30,732 [WARNING] root: Trial 19 of subject 0001 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:30,733 [ERROR] root: Cut trial error for trial 19 of subject 0001: Trial 19 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 19 has less than 8 correct targets.
# 2025-05-11 22:52:30,855 [WARNING] root: Trial 6 of subject 0002 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:30,856 [ERROR] root: Cut trial error for trial 6 of subject 0002: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:30,976 [WARNING] root: Trial 15 of subject 0004 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:30,976 [ERROR] root: Cut trial error for trial 15 of subject 0004: Trial 15 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-05-11 22:52:31,093 [WARNING] root: Trial 8 of subject 0005 has 2 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,094 [ERROR] root: Cut trial error for trial 8 of subject 0005: Trial 8 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 8 has less than 8 correct targets.
# 2025-05-11 22:52:31,111 [WARNING] root: Trial 15 of subject 0005 has 4 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,112 [ERROR] root: Cut trial error for trial 15 of subject 0005: Trial 15 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-05-11 22:52:31,156 [WARNING] root: Trial 20 of subject 0005 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,156 [ERROR] root: Cut trial error for trial 20 of subject 0005: Trial 20 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 20 has less than 8 correct targets.
# 2025-05-11 22:52:31,196 [WARNING] root: Trial 3 of subject 0005 has 2 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,196 [ERROR] root: Cut trial error for trial 3 of subject 0005: Trial 3 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 3 has less than 8 correct targets.
# 2025-05-11 22:52:31,204 [WARNING] root: Trial 12 of subject 0005 has 3 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,205 [ERROR] root: Cut trial error for trial 12 of subject 0005: Trial 12 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 12 has less than 8 correct targets.
# 2025-05-11 22:52:31,303 [WARNING] root: Trial 16 of subject 0007 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,304 [ERROR] root: Cut trial error for trial 16 of subject 0007: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 16 has less than 8 correct targets.
# 2025-05-11 22:52:31,307 [WARNING] root: Trial 3 of subject 0007 has 2 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,307 [ERROR] root: Cut trial error for trial 3 of subject 0007: Trial 3 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 3 has less than 8 correct targets.
# 2025-05-11 22:52:31,323 [WARNING] root: Trial 9 of subject 0007 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,323 [ERROR] root: Cut trial error for trial 9 of subject 0007: Trial 9 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 9 has less than 8 correct targets.
# 2025-05-11 22:52:31,325 [WARNING] root: Trial 15 of subject 0007 has 3 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,326 [ERROR] root: Cut trial error for trial 15 of subject 0007: Trial 15 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-05-11 22:52:31,329 [WARNING] root: Trial 11 of subject 0007 has 2 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,329 [ERROR] root: Cut trial error for trial 11 of subject 0007: Trial 11 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 11 has less than 8 correct targets.
# 2025-05-11 22:52:31,331 [WARNING] root: Trial 10 of subject 0007 has 3 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,332 [ERROR] root: Cut trial error for trial 10 of subject 0007: Trial 10 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 10 has less than 8 correct targets.
# 2025-05-11 22:52:31,334 [WARNING] root: Trial 1 of subject 0007 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,335 [ERROR] root: Cut trial error for trial 1 of subject 0007: Trial 1 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 1 has less than 8 correct targets.
# 2025-05-11 22:52:31,344 [WARNING] root: Trial 6 of subject 0007 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,344 [ERROR] root: Cut trial error for trial 6 of subject 0007: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:31,347 [WARNING] root: Trial 2 of subject 0007 has 4 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,347 [ERROR] root: Cut trial error for trial 2 of subject 0007: Trial 2 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 2 has less than 8 correct targets.
# 2025-05-11 22:52:31,469 [WARNING] root: Trial 16 of subject 0008 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,469 [ERROR] root: Cut trial error for trial 16 of subject 0008: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 16 has less than 8 correct targets.
# 2025-05-11 22:52:31,706 [WARNING] root: Trial 1 of subject 0011 has 1 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,706 [ERROR] root: Cut trial error for trial 1 of subject 0011: Trial 1 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 1 has less than 8 correct targets.
# 2025-05-11 22:52:31,814 [WARNING] root: Trial 19 of subject 0012 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,814 [ERROR] root: Cut trial error for trial 19 of subject 0012: Trial 19 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 19 has less than 8 correct targets.
# 2025-05-11 22:52:31,847 [WARNING] root: Trial 4 of subject 0012 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,848 [ERROR] root: Cut trial error for trial 4 of subject 0012: Trial 4 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 4 has less than 8 correct targets.
# 2025-05-11 22:52:31,867 [WARNING] root: Trial 6 of subject 0013 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,868 [ERROR] root: Cut trial error for trial 6 of subject 0013: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:31,873 [WARNING] root: Trial 16 of subject 0013 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,873 [ERROR] root: Cut trial error for trial 16 of subject 0013: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 16 has less than 8 correct targets.
# 2025-05-11 22:52:31,875 [WARNING] root: Trial 8 of subject 0013 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,876 [ERROR] root: Cut trial error for trial 8 of subject 0013: Trial 8 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 8 has less than 8 correct targets.
# 2025-05-11 22:52:31,900 [WARNING] root: Trial 19 of subject 0013 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,901 [ERROR] root: Cut trial error for trial 19 of subject 0013: Trial 19 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 19 has less than 8 correct targets.
# 2025-05-11 22:52:31,903 [WARNING] root: Trial 4 of subject 0013 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,904 [ERROR] root: Cut trial error for trial 4 of subject 0013: Trial 4 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 4 has less than 8 correct targets.
# 2025-05-11 22:52:31,913 [WARNING] root: Trial 0 of subject 0013 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:31,914 [ERROR] root: Cut trial error for trial 0 of subject 0013: Trial 0 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 0 has less than 8 correct targets.
# 2025-05-11 22:52:32,074 [WARNING] root: Trial 8 of subject 0015 has 4 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,074 [ERROR] root: Cut trial error for trial 8 of subject 0015: Trial 8 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 8 has less than 8 correct targets.
# 2025-05-11 22:52:32,076 [WARNING] root: Trial 2 of subject 0015 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,076 [ERROR] root: Cut trial error for trial 2 of subject 0015: Trial 2 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 2 has less than 8 correct targets.
# 2025-05-11 22:52:32,088 [WARNING] root: Trial 15 of subject 0015 has 4 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,088 [ERROR] root: Cut trial error for trial 15 of subject 0015: Trial 15 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-05-11 22:52:32,103 [WARNING] root: Trial 12 of subject 0015 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,104 [ERROR] root: Cut trial error for trial 12 of subject 0015: Trial 12 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 12 has less than 8 correct targets.
# 2025-05-11 22:52:32,117 [WARNING] root: Trial 7 of subject 0015 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,117 [ERROR] root: Cut trial error for trial 7 of subject 0015: Trial 7 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 7 has less than 8 correct targets.
# 2025-05-11 22:52:32,130 [WARNING] root: Trial 10 of subject 0015 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,131 [ERROR] root: Cut trial error for trial 10 of subject 0015: Trial 10 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 10 has less than 8 correct targets.
# 2025-05-11 22:52:32,135 [WARNING] root: Trial 4 of subject 0015 has 3 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,136 [ERROR] root: Cut trial error for trial 4 of subject 0015: Trial 4 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 4 has less than 8 correct targets.
# 2025-05-11 22:52:32,138 [WARNING] root: Trial 17 of subject 0015 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,138 [ERROR] root: Cut trial error for trial 17 of subject 0015: Trial 17 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 17 has less than 8 correct targets.
# 2025-05-11 22:52:32,147 [WARNING] root: Trial 6 of subject 0015 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,147 [ERROR] root: Cut trial error for trial 6 of subject 0015: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:32,250 [WARNING] root: Trial 13 of subject 0017 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,250 [ERROR] root: Cut trial error for trial 13 of subject 0017: Trial 13 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 13 has less than 8 correct targets.
# 2025-05-11 22:52:32,280 [WARNING] root: Trial 1 of subject 0017 has 1 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,281 [ERROR] root: Cut trial error for trial 1 of subject 0017: Trial 1 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 1 has less than 8 correct targets.
# 2025-05-11 22:52:32,465 [WARNING] root: Trial 5 of subject 0019 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,465 [ERROR] root: Cut trial error for trial 5 of subject 0019: Trial 5 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 5 has less than 8 correct targets.
# 2025-05-11 22:52:32,498 [WARNING] root: Trial 19 of subject 0019 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:32,498 [ERROR] root: Cut trial error for trial 19 of subject 0019: Trial 19 has less than 8 correct targets.
# Traceback (most recent call last):
# ...
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 15 has less than 8 correct targets.
# 2025-05-11 22:52:39,728 [WARNING] root: Trial 10 of subject 0094 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,729 [ERROR] root: Cut trial error for trial 10 of subject 0094: Trial 10 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 10 has less than 8 correct targets.
# 2025-05-11 22:52:39,736 [WARNING] root: Trial 16 of subject 0094 has 3 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,737 [ERROR] root: Cut trial error for trial 16 of subject 0094: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 16 has less than 8 correct targets.
# 2025-05-11 22:52:39,739 [WARNING] root: Trial 12 of subject 0094 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,739 [ERROR] root: Cut trial error for trial 12 of subject 0094: Trial 12 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 12 has less than 8 correct targets.
# 2025-05-11 22:52:39,741 [WARNING] root: Trial 11 of subject 0094 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,742 [ERROR] root: Cut trial error for trial 11 of subject 0094: Trial 11 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 11 has less than 8 correct targets.
# 2025-05-11 22:52:39,744 [WARNING] root: Trial 8 of subject 0094 has 2 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,745 [ERROR] root: Cut trial error for trial 8 of subject 0094: Trial 8 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 8 has less than 8 correct targets.
# 2025-05-11 22:52:39,746 [WARNING] root: Trial 6 of subject 0094 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,747 [ERROR] root: Cut trial error for trial 6 of subject 0094: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:39,778 [WARNING] root: Trial 5 of subject 0095 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,778 [ERROR] root: Cut trial error for trial 5 of subject 0095: Trial 5 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 5 has less than 8 correct targets.
# 2025-05-11 22:52:39,784 [WARNING] root: Trial 16 of subject 0095 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,785 [ERROR] root: Cut trial error for trial 16 of subject 0095: Trial 16 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 16 has less than 8 correct targets.
# 2025-05-11 22:52:39,811 [WARNING] root: Trial 10 of subject 0095 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,811 [ERROR] root: Cut trial error for trial 10 of subject 0095: Trial 10 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 10 has less than 8 correct targets.
# 2025-05-11 22:52:39,825 [WARNING] root: Trial 3 of subject 0095 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:39,826 [ERROR] root: Cut trial error for trial 3 of subject 0095: Trial 3 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 3 has less than 8 correct targets.
# 2025-05-11 22:52:40,043 [WARNING] root: Trial 1 of subject 0098 has 6 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:40,044 [ERROR] root: Cut trial error for trial 1 of subject 0098: Trial 1 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 1 has less than 8 correct targets.
# 2025-05-11 22:52:40,103 [WARNING] root: Trial 20 of subject 0098 has 5 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:40,104 [ERROR] root: Cut trial error for trial 20 of subject 0098: Trial 20 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 20 has less than 8 correct targets.
# 2025-05-11 22:52:40,161 [WARNING] root: Trial 6 of subject 0099 has 7 correct target touches, but the minimum required is 8.
# 2025-05-11 22:52:40,161 [ERROR] root: Cut trial error for trial 6 of subject 0099: Trial 6 has less than 8 correct targets.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics/metrics_calculator.py", line 150, in _attempt_cut_trial
#     return cut_trial(trial, correct_targets_minimum, subject, subject_id, cut_criteria)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 35, in cut_trial
#     return cut_trial_at_minimum_targets(correct_targets_minimum, subject, subject_id, trial)
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/cut_criteria/cut_implementation.py", line 68, in cut_trial_at_minimum_targets
#     raise ValueError(f"Trial {trial.id} has less than {correct_targets_minimum} correct targets.")
# ValueError: Trial 6 has less than 8 correct targets.
# 2025-05-11 22:52:40,301 [INFO] root: Metrics successfully saved to /home/gianluca/Research/tmt-analysis/data/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  zigzag_amplitude  \
# 0                          2         0.262139               NaN
# 1                          3         0.262139          1.166154
# 2                          4         0.262139               NaN
# 3                          5         0.262139          1.125605
# 4                          6         0.262139               NaN
#
#    total_distance  ...  state_transitions  hesitation_ratio  \
# 0        2.078944  ...               12.0          0.746344
# 1        1.714647  ...               13.0          0.406230
# 2        2.069694  ...               14.0          0.000000
# 3        1.824671  ...               12.0          0.000000
# 4        1.687751  ...               12.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    correct_targets_touches  wrong_targets_touches  number_of_crosses  \
# 0                      8.0                    0.0                NaN
# 1                      8.0                    2.0                NaN
# 2                      8.0                    0.0                NaN
# 3                      8.0                    1.0                NaN
# 4                      8.0                    2.0                NaN
#
#    invalid_cause
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 42 columns]
# Len of subjects: 99

# %%
from neurotask.tmt.metrics.speed_metrics import calculate_speeds_between_cursor_positions, \
    calculate_accelerations_between_cursor_positions
from matplotlib import pyplot as plt
from build.lib.neurotask.tmt.model.tmt_model import TMTTrial


def plot_with_color(trial: TMTTrial, canvas_size: int, target_radius: float, color_by='time'):
    """
    Plotea la trayectoria del cursor junto con los targets en un gráfico,
    ajustando el tamaño del gráfico al tamaño del canvas y dibujando círculos
    alrededor de los targets con su contenido. La trayectoria del cursor se
    dibuja con puntos cuyos colores cambian en función del tiempo, la velocidad o la aceleración.
    El primer clic en el target se destaca con un marcador especial.

    Parameters:
    - trial: TMTTrial, el trial con la trayectoria del cursor y los targets.
    - canvas_size: int, tamaño del canvas (ancho y alto).
    - target_radius: float, radio de los círculos que rodean los targets.
    - color_by: str, 'time', 'speed' o 'acceleration', determina si el color de los puntos cambia en función del tiempo, velocidad o aceleración.
    """

    # Extraer la posición de los targets
    target_x = [target.position.x for target in trial.stimuli]
    target_y = [target.position.y for target in trial.stimuli]
    target_contents = [target.content for target in trial.stimuli]

    cursor_trail_from_first_click = trial.get_cursor_trail_from_start()
    # Extraer la trayectoria del cursor
    cursor_x = [cursor_info.position.x for cursor_info in cursor_trail_from_first_click]
    cursor_y = [cursor_info.position.y for cursor_info in cursor_trail_from_first_click]
    cursor_times = [cursor_info.time for cursor_info in cursor_trail_from_first_click]

    if color_by == 'time':
        # Normalizar tiempos para que estén en el rango [0, 1]
        norm = plt.Normalize(min(cursor_times), max(cursor_times))
        colors = plt.cm.viridis(norm(cursor_times))  # Usar un mapa de colores para el tiempo
    elif color_by == 'speed':
        speeds = calculate_speeds_between_cursor_positions(trial)
        speeds = [0] + speeds  # Para igualar el número de puntos con las velocidades calculadas
        norm = plt.Normalize(min(speeds), max(speeds))
        colors = plt.cm.viridis(norm(speeds))  # Usar un mapa de colores para la velocidad
    elif color_by == 'acceleration':
        accelerations = calculate_accelerations_between_cursor_positions(trial)
        accelerations = [0, 0] + accelerations  # Igualar el número de puntos (2 primeros puntos sin aceleración)
        norm = plt.Normalize(min(accelerations), max(accelerations))
        colors = plt.cm.viridis(norm(accelerations))  # Usar un mapa de colores para la aceleración
    else:
        #do not color
        # all white
        norm = plt.Normalize(0, 1)
        colors = ['white'] * len(cursor_x)
        

    # Crear el gráfico
    fig, ax = plt.subplots(figsize=(8, 8))

    # Dibujar la trayectoria del cursor como líneas coloreadas por tiempo o velocidad
    for i in range(len(cursor_x) - 1):
        plt.plot([cursor_x[i], cursor_x[i + 1]],
                 [cursor_y[i], cursor_y[i + 1]],
                 color=colors[i], linewidth=2, zorder=4)

    # Dibujar los targets como círculos con el contenido dentro
    for x, y, content in zip(target_x, target_y, target_contents):
        circle = plt.Circle((x, y), target_radius, color='red', alpha=0.3, zorder=5)
        plt.gca().add_patch(circle)
        # Añadir el contenido del target en el centro del círculo
        plt.text(x, y, content, color='black', fontsize=8, ha='center', va='center', zorder=6)

    # Destacar el primer clic
    if trial.start:
        fc_x = trial.start.position.x
        fc_y = trial.start.position.y
        plt.scatter(fc_x, fc_y, color='cyan', edgecolor='black', s=100, label='First Click', zorder=7,
                    marker='o', alpha=0.3)

    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar_label = 'Time' if color_by == 'time' else 'Speed' if color_by == 'speed' else 'Acceleration'
    cbar = fig.colorbar(sm, ax=ax, label=cbar_label)

    # # Set plot limits based on canvas size
    # ax.set_xlim(-canvas_size, canvas_size)
    # ax.set_ylim(canvas_size, -canvas_size,)  # Inverted Y-axis if needed

    # Add labels and title
    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.set_title('Cursor Trail with Targets')

    # Ensure equal aspect ratio
    ax.set_aspect('equal', adjustable='box')

    # Add legend
    ax.legend()

    return fig

# %%
from src.hand_analysis.loader.load_last_split import load_last_analysis
train_set, _ = load_last_analysis()
# Out:
# 2025-05-11 22:52:43,749 [INFO] root: Loading split from /home/gianluca/Research/tmt-analysis/data/hand_analysis/2025-05-11_15-56-57

# %%
for subject_id in ["0063", "0091", "0022"]:
    subject_analysis = train_set[train_set['subject_id'] == int(subject_id)]
    subject = experiment.subjects[subject_id]
    for trial in sorted(subject.testing_trials, key=lambda x: x.id):
        print("Trial ID:", trial.id)
        print("Trial Type:", trial.trial_type)
        print("Trial order:", trial.order_of_appearance)
        print("Correct targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['correct_targets_touches'].values[0])
        print("Wrong targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['wrong_targets_touches'].values[0])
    
        plot_with_color(trial, subject.canvas_size, subject.target_radius)
        plt.show()
        break
# Out:
# Trial ID: 0
# Trial Type: TrialType.PART_B
# Trial order: 9
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 1.0
# Trial ID: 0
# Trial Type: TrialType.PART_A
# Trial order: 16
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 1.0
# Trial ID: 0
# Trial Type: TrialType.PART_B
# Trial order: 9
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 4.0

# %%
import numpy as np
from typing import List, Tuple

def get_ideal_target_segments(
    trial: TMTTrial,
    num_interpolation_points: int = 20
) -> List[List[Tuple[float, float]]]:
    """
    Genera los segmentos ideales de recorrido entre targets consecutivos
    usando interpolación lineal.

    :param trial: TMTTrial con la lista de stimuli en orden de ejecución.
    :param num_interpolation_points: número de puntos a interpolar por segmento
                                     (incluyendo los extremos).
    :return: Lista de segmentos; cada segmento es una lista de (x, y) interpolados.
    """
    segments: List[List[Tuple[float, float]]] = []
    stimuli = trial.stimuli

    # Si hay menos de 2 targets, no hay segmentos
    if len(stimuli) < 2:
        return segments

    # Para cada par consecutivo de targets
    for start_tgt, end_tgt in zip(stimuli[:-1], stimuli[1:]):
        x0, y0 = start_tgt.position.x, start_tgt.position.y
        x1, y1 = end_tgt.position.x,   end_tgt.position.y

        # Generar valores lineales entre x0→x1 y y0→y1
        xs = np.linspace(x0, x1, num=num_interpolation_points)
        ys = np.linspace(y0, y1, num=num_interpolation_points)

        # Combinar en lista de tuplas y guardarla
        segment = [(float(x), float(y)) for x, y in zip(xs, ys)]
        segments.append(segment)

    return segments

# %%
import matplotlib.pyplot as plt
from typing import List, Tuple
import numpy as np
def plot_trial_with_ideal_path(
    trial: TMTTrial,
    num_interpolation_points: int = 20,
    show_actual_path: bool = True
) -> None:
    """
    Grafica un trial mostrando:
      - Las posiciones de los targets (estímulos) como puntos.
      - El camino ideal (interpolación lineal entre cada par de targets).
      - Opcionalmente, la trayectoria real del cursor.

    :param trial: instancia de TMTTrial a graficar.
    :param num_interpolation_points: resolución de la interpolación lineal.
    :param show_actual_path: si es True, sobrepone la trayectoria real del cursor.
    """
    # Obtener posiciones de los targets
    xs_targets = [t.position.x for t in trial.stimuli]
    ys_targets = [t.position.y for t in trial.stimuli]

    # Obtener segmentos ideales
    ideal_segments: List[List[Tuple[float, float]]] = \
        get_ideal_target_segments(trial, num_interpolation_points)

    # Empieza la figura
    plt.figure()
    # Graficar targets
    plt.scatter(xs_targets, ys_targets, marker='o', label='Targets')

    # Graficar caminos ideales
    for segment in ideal_segments:
        xs, ys = zip(*segment)
        plt.plot(xs, ys, linestyle='-', label='Ideal path' if segment is ideal_segments[0] else "")

    # Graficar trayectoria real si se desea
    if show_actual_path:
        # suponiendo que trial.get_cursor_trail_from_start() da una lista de CursorInfo con .position
        trail = trial.get_cursor_trail_from_start()
        xs_real = [ci.position.x for ci in trail]
        ys_real = [ci.position.y for ci in trail]
        plt.plot(xs_real, ys_real, linestyle='--', label='Actual path')

    # Ajustes finales
    plt.title(f"Trial {trial.id}")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axis('equal')  # para mantener proporción real
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
from typing import List, Tuple

def plot_trial_with_ideal_and_actual(
    trial: TMTTrial,
    canvas_size: int,
    target_radius: float,
    color_by: str = 'time',
    num_interpolation_points: int = 20
) -> plt.Figure:
    """
    Usa `plot_with_color` para dibujar la trayectoria real coloreada,
    y sobrepone el camino ideal interpolado entre cada par consecutivo
    de targets.

    :param trial: TMTTrial
    :param canvas_size: tamaño del canvas
    :param target_radius: radio de los círculos de los targets
    :param color_by: 'time', 'speed' o 'acceleration'
    :param num_interpolation_points: resolución de la interpolación ideal
    :return: objeto matplotlib Figure
    """
    # 1) Grafica la trayectoria real y los targets
    fig = plot_with_color(trial, canvas_size, target_radius, color_by)
    ax = fig.axes[0]

    # 2) Calcula los segmentos ideales con interpolación lineal
    ideal_segments: List[List[Tuple[float, float]]] = \
        get_ideal_target_segments(trial, num_interpolation_points)

    # 3) Sobrepone el camino ideal
    first = True
    for segment in ideal_segments:
        xs, ys = zip(*segment)
        ax.plot(
            xs, ys,
            linestyle='--',
            linewidth=2,
            color='black',
            label='Ideal path' if first else None,
            zorder=3
        )
        first = False

    # 4) Ajusta leyenda (evitar duplicados)
    handles, labels = ax.get_legend_handles_labels()
    # Filtrar etiquetas únicas
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys())

    return fig

# %%
from neurotask.tmt.model.tmt_model import TMTTarget, CursorInfo, TMTTrial
from neurotask.tmt.metrics.targets_touch_calculator import get_all_trails_between_targets

import matplotlib.pyplot as plt
from typing import List, Tuple

def plot_segments_between_targets(
    trial: TMTTrial,
    canvas_size: int,
    target_radius: float
) -> plt.Figure:
    """
    Dibuja la trayectoria real coloreada (usando plot_with_color)
    y sobrepone cada segmento entre targets con un color distinto.

    :param trial: instancia de TMTTrial
    :param canvas_size: tamaño del canvas
    :param target_radius: radio para detección de toques
    :param color_by: 'time', 'speed' o 'acceleration'
    :return: objeto Figure de matplotlib
    """
    # Primeramente dibujamos la base (trayectoria + targets)
    fig = plot_with_color(trial, canvas_size, target_radius, None)
    ax = fig.axes[0]

    # Obtenemos los segmentos ideales de recorrido real entre targets
    segments: List[Tuple[TMTTarget, List[CursorInfo]]] = \
        get_all_trails_between_targets(trial, target_radius)
    print(segments)

    # Usamos un colormap cualitativo para distinguir segmentos
    cmap = plt.get_cmap('tab10')
    
    for idx, (target, cursor_segment) in enumerate(segments):
        xs = [ci.position.x for ci in cursor_segment]
        ys = [ci.position.y for ci in cursor_segment]
        color = cmap(idx % cmap.N)
        ax.plot(
            xs, ys,
            linestyle='-',
            linewidth=5,
            color=color,
            label=f"To {target.content}"
        )

    # Ajustar leyenda para no duplicar etiquetas
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='best')

    return fig

# %%
for subject_id in ["0063", "0091", "0022"]:
    subject_analysis = train_set[train_set['subject_id'] == int(subject_id)]
    subject = experiment.subjects[subject_id]
    for trial in sorted(subject.testing_trials, key=lambda x: x.id):
        print("Trial ID:", trial.id)
        print("Trial Type:", trial.trial_type)
        print("Trial order:", trial.order_of_appearance)
        print("Correct targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['correct_targets_touches'].values[0])
        print("Wrong targets touches from analysis:", subject_analysis[subject_analysis['trial_id'] == trial.id]['wrong_targets_touches'].values[0])
    
        plot_with_color(trial, subject.canvas_size, subject.target_radius)
        plot_trial_with_ideal_path(trial, num_interpolation_points=50, show_actual_path=True)
        plot_trial_with_ideal_and_actual(trial, subject.canvas_size, subject.target_radius, color_by='time', num_interpolation_points=50)
        plot_segments_between_targets(trial, subject.canvas_size, subject.target_radius)
        break
        
    break
# Out:
# Trial ID: 0
# Trial Type: TrialType.PART_B
# Trial order: 9
# Correct targets touches from analysis: 8.0
# Wrong targets touches from analysis: 1.0
# [(TMTTarget(content='A', position=Coordinate(x=0.2713626666666667, y=0.35828533333333323)), [CursorInfo(position=Coordinate(x=-0.04537037, y=0.08055556), time=1.6132666999474168), CursorInfo(position=Coordinate(x=-0.041666668, y=0.083333336), time=1.6465799999423325), CursorInfo(position=Coordinate(x=-0.039814815, y=0.085185185), time=1.6799576999619603), CursorInfo(position=Coordinate(x=-0.03888889, y=0.08611111), time=1.713031499646604), CursorInfo(position=Coordinate(x=-0.037962962, y=0.08611111), time=1.746553699951619), CursorInfo(position=Coordinate(x=-0.036111113, y=0.087037034), time=1.779952900018543), CursorInfo(position=Coordinate(x=-0.03425926, y=0.08888889), time=1.8130545997992158), CursorInfo(position=Coordinate(x=-0.03425926, y=0.08888889), time=1.8463760996237397), CursorInfo(position=Coordinate(x=-0.03425926, y=0.08888889), time=1.8799278000369668), CursorInfo(position=Coordinate(x=-0.032407407, y=0.08981481), time=1.913238599896431), CursorInfo(position=Coordinate(x=-0.025, y=0.09074074), time=1.9465620997361839), CursorInfo(position=Coordinate(x=-0.014814815, y=0.09351852), time=1.9799318998120725), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.013136999681592), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.046375900041312), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.079717299900949), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.1130555998533964), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.146423999685794), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.179756199941039), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.2130340998992324), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.2463644999079406), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.2797448998317122), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.3130691000260413), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.346419899724424), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.379713799804449), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.413056700024754), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.446411699987948), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.4797768997959793), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.513059899676591), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.5464071999303997), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.5797202000394464), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.6130911000072956), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.6463827998377383), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.679774799849838), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.7130452999845147), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.7464266000315547), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.779750899877399), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.8131010998040438), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.8463705996982753), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.879701499827206), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.913063599728048), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.946390299592167), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=2.9797485996969044), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=3.0130850998684764), CursorInfo(position=Coordinate(x=-0.0129629625, y=0.09537037), time=3.046396399848163), CursorInfo(position=Coordinate( ...
