# %%
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_default_parameters
from src.metadata.add_metadata import add_metadata_to_metrics

# %%
analysis = run_analysis_with_default_parameters()
metrics_df = analysis.get_metrics_dataframe()
metrics_df.head()
# Out:
# 2025-04-05 09:43:11,968 [INFO] root: Processing subject: 0001, group: control
# 2025-04-05 09:43:12,251 [INFO] root: Processing subject: 0002, group: control
# 2025-04-05 09:43:12,505 [INFO] root: Processing subject: 0003, group: MCI
# 2025-04-05 09:43:12,749 [INFO] root: Processing subject: 0004, group: MCI
# 2025-04-05 09:43:12,938 [INFO] root: Processing subject: 0005, group: MCI
# 2025-04-05 09:43:13,208 [INFO] root: Processing subject: 0006, group: control
# 2025-04-05 09:43:13,379 [INFO] root: Processing subject: 0007, group: control
# 2025-04-05 09:43:13,655 [INFO] root: Processing subject: 0008, group: MCI
# 2025-04-05 09:43:13,820 [INFO] root: Processing subject: 0009, group: MCI
# 2025-04-05 09:43:13,988 [INFO] root: Processing subject: 0010, group: control
# 2025-04-05 09:43:14,255 [INFO] root: Processing subject: 0011, group: MCI
# 2025-04-05 09:43:14,448 [INFO] root: Processing subject: 0012, group: MCI
# 2025-04-05 09:43:14,630 [INFO] root: Processing subject: 0013, group: MCI
# 2025-04-05 09:43:14,965 [INFO] root: Processing subject: 0014, group: control
# 2025-04-05 09:43:15,130 [INFO] root: Processing subject: 0015, group: MCI
# 2025-04-05 09:43:15,326 [INFO] root: Processing subject: 0016, group: MCI
# 2025-04-05 09:43:15,491 [INFO] root: Processing subject: 0017, group: MCI
# 2025-04-05 09:43:15,673 [INFO] root: Processing subject: 0018, group: control
# 2025-04-05 09:43:16,049 [INFO] root: Processing subject: 0019, group: MCI
# 2025-04-05 09:43:16,241 [INFO] root: Processing subject: 0020, group: MCI
# 2025-04-05 09:43:16,431 [INFO] root: Processing subject: 0021, group: control
# 2025-04-05 09:43:16,621 [INFO] root: Processing subject: 0022, group: control
# 2025-04-05 09:43:16,844 [INFO] root: Processing subject: 0023, group: control
# 2025-04-05 09:43:17,258 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-04-05 09:43:17,451 [INFO] root: Processing subject: 0025, group: MCI
# 2025-04-05 09:43:17,675 [INFO] root: Processing subject: 0026, group: control
# 2025-04-05 09:43:17,852 [INFO] root: Processing subject: 0027, group: MCI
# 2025-04-05 09:43:18,042 [INFO] root: Processing subject: 0028, group: control
# 2025-04-05 09:43:18,215 [INFO] root: Processing subject: 0029, group: control
# 2025-04-05 09:43:18,648 [INFO] root: Processing subject: 0030, group: control
# 2025-04-05 09:43:18,825 [INFO] root: Processing subject: 0031, group: control
# 2025-04-05 09:43:19,019 [INFO] root: Processing subject: 0032, group: control
# 2025-04-05 09:43:19,169 [INFO] root: Processing subject: 0033, group: control
# 2025-04-05 09:43:19,354 [INFO] root: Processing subject: 0034, group: control
# 2025-04-05 09:43:19,545 [INFO] root: Processing subject: 0035, group: control
# 2025-04-05 09:43:19,726 [INFO] root: Processing subject: 0036, group: control
# 2025-04-05 09:43:20,212 [INFO] root: Processing subject: 0037, group: control
# 2025-04-05 09:43:20,370 [INFO] root: Processing subject: 0038, group: control
# 2025-04-05 09:43:20,535 [INFO] root: Processing subject: 0039, group: control
# 2025-04-05 09:43:20,705 [INFO] root: Processing subject: 0040, group: control
# 2025-04-05 09:43:20,882 [INFO] root: Processing subject: 0041, group: control
# 2025-04-05 09:43:21,042 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-04-05 09:43:21,225 [INFO] root: Processing subject: 0043, group: control
# 2025-04-05 09:43:21,397 [INFO] root: Processing subject: 0044, group: control
# 2025-04-05 09:43:21,574 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-04-05 09:43:21,761 [INFO] root: Processing subject: 0046, group: MCI
# 2025-04-05 09:43:22,315 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-04-05 09:43:22,493 [INFO] root: Processing subject: 0048, group: MCI
# 2025-04-05 09:43:22,680 [INFO] root: Processing subject: 0049, group: MCI
# 2025-04-05 09:43:22,894 [INFO] root: Processing subject: 0050, group: MCI
# 2025-04-05 09:43:23,059 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:43:23,090 [INFO] root: Processing subject: 0051, group: MCI
# 2025-04-05 09:43:23,245 [INFO] root: Processing subject: 0052, group: MCI
# 2025-04-05 09:43:23,429 [INFO] root: Processing subject: 0053, group: MCI
# 2025-04-05 09:43:23,565 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:43:23,567 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:43:23,593 [INFO] root: Processing subject: 0054, group: MCI
# 2025-04-05 09:43:23,771 [INFO] root: Processing subject: 0055, group: MCI
# 2025-04-05 09:43:23,940 [INFO] root: Processing subject: 0056, group: control
# 2025-04-05 09:43:24,128 [INFO] root: Processing subject: 0057, group: MCI
# 2025-04-05 09:43:24,762 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-04-05 09:43:24,979 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-04-05 09:43:25,157 [INFO] root: Processing subject: 0060, group: MCI
# 2025-04-05 09:43:25,346 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-04-05 09:43:25,525 [INFO] root: Processing subject: 0062, group: MCI
# 2025-04-05 09:43:25,668 [INFO] root: Processing subject: 0063, group: control
# 2025-04-05 09:43:25,835 [INFO] root: Processing subject: 0064, group: MCI
# 2025-04-05 09:43:26,030 [INFO] root: Processing subject: 0065, group: MCI
# 2025-04-05 09:43:26,217 [INFO] root: Processing subject: 0066, group: MCI
# 2025-04-05 09:43:26,425 [INFO] root: Processing subject: 0067, group: MCI
# 2025-04-05 09:43:26,600 [INFO] root: Processing subject: 0068, group: MCI
# 2025-04-05 09:43:26,791 [INFO] root: Processing subject: 0069, group: MCI
# 2025-04-05 09:43:26,954 [INFO] root: Processing subject: 0070, group: control
# 2025-04-05 09:43:27,132 [INFO] root: Processing subject: 0071, group: control
# 2025-04-05 09:43:27,899 [INFO] root: Processing subject: 0072, group: MCI
# 2025-04-05 09:43:28,077 [INFO] root: Processing subject: 0073, group: MCI
# 2025-04-05 09:43:28,275 [INFO] root: Processing subject: 0074, group: control
# 2025-04-05 09:43:28,432 [INFO] root: Processing subject: 0075, group: MCI
# 2025-04-05 09:43:28,620 [INFO] root: Processing subject: 0076, group: MCI
# 2025-04-05 09:43:28,791 [INFO] root: Processing subject: 0077, group: MCI
# 2025-04-05 09:43:28,970 [INFO] root: Processing subject: 0078, group: control
# 2025-04-05 09:43:29,161 [INFO] root: Processing subject: 0079, group: control
# 2025-04-05 09:43:29,373 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:43:29,391 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-04-05 09:43:29,577 [INFO] root: Processing subject: 0081, group: MCI
# 2025-04-05 09:43:29,749 [INFO] root: Processing subject: 0082, group: MCI
# 2025-04-05 09:43:29,929 [INFO] root: Processing subject: 0083, group: control
# 2025-04-05 09:43:30,107 [INFO] root: Processing subject: 0084, group: control
# 2025-04-05 09:43:30,299 [INFO] root: Processing subject: 0085, group: control
# 2025-04-05 09:43:30,473 [INFO] root: Processing subject: 0086, group: control
# 2025-04-05 09:43:30,659 [INFO] root: Processing subject: 0087, group: control
# 2025-04-05 09:43:31,516 [INFO] root: Processing subject: 0088, group: MCI
# 2025-04-05 09:43:31,713 [INFO] root: Processing subject: 0089, group: control
# 2025-04-05 09:43:31,935 [INFO] root: Processing subject: 0090, group: control
# 2025-04-05 09:43:32,118 [INFO] root: Processing subject: 0091, group: control
# 2025-04-05 09:43:32,286 [INFO] root: Processing subject: 0092, group: MCI
# 2025-04-05 09:43:32,478 [INFO] root: Processing subject: 0093, group: MCI
# 2025-04-05 09:43:32,668 [INFO] root: Processing subject: 0094, group: MCI
# 2025-04-05 09:43:32,868 [INFO] root: Processing subject: 0095, group: control
# 2025-04-05 09:43:33,049 [INFO] root: Processing subject: 0096, group: MCI
# 2025-04-05 09:43:33,223 [INFO] root: Processing subject: 0097, group: MCI
# 2025-04-05 09:43:33,396 [INFO] root: Processing subject: 0098, group: MCI
# 2025-04-05 09:43:33,577 [INFO] root: Processing subject: 0099, group: MCI
# 2025-04-05 09:43:33,754 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-04-05 09:43:37,961 [ERROR] root: Error processing subject 0050: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-05 09:43:38,143 [ERROR] root: Error processing subject 0053: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-05 09:43:40,045 [ERROR] root: Error processing trial 12 for subject 0076: 'bool' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 89, in generate_rows_for_subject
#     trial_metrics = compute_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 239, in compute_trial_metrics
#     segmentation = calculate_segmentation_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 321, in calculate_segmentation_trial_metrics
#     classified_positions = classify_cursor_positions_with_hesitation(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 93, in classify_cursor_positions_with_hesitation
#     over_target = over_target_flags[i][0]
# TypeError: 'bool' object is not subscriptable
# 2025-04-05 09:43:40,295 [ERROR] root: Error processing subject 0079: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-05 09:43:41,863 [INFO] root: Metrics successfully saved to /home/gianluca/Research/tmt-analysis/data/hand_analysis/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001        18     PART_A   35      M      True
# 1       0001        14     PART_B   35      M      True
# 2       0001         8     PART_A   35      M      True
# 3       0001         7     PART_B   35      M      True
# 4       0001        11     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                         18         0.262139        3.251782  16959  ...
# 1                         14         0.262139        2.705068  25001  ...
# 2                          8         0.262139        3.756078  18105  ...
# 3                          7         0.262139        3.451943  18091  ...
# 4                         11         0.262139        3.522551  15807  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.422087          0.167829               27.0          0.106139
# 1          0.455864          0.097937               19.0          0.562157
# 2          0.702588          0.215688               26.0          0.654418
# 3          0.427423          0.162585               25.0          0.203475
# 4          0.554113          0.184134               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration  \
# 0                2.0          0.151046      0.166710
# 1                1.0          1.686070      1.686070
# 2                1.0          4.333857      4.333857
# 3                1.0          0.735873      0.735873
# 4                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  invalid_cause
# 0  [0.16670990000000074, 0.1353818999999703]                NaN            NaN
# 1                       [1.6860698000000411]                NaN            NaN
# 2                        [4.333857099999932]                NaN            NaN
# 3                       [0.7358727999999246]                NaN            NaN
# 4                                         []                NaN            NaN
#
# [5 rows x 41 columns]
# Len of subjects: 99
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001        18     PART_A   35      M      True
# 1       0001        14     PART_B   35      M      True
# 2       0001         8     PART_A   35      M      True
# 3       0001         7     PART_B   35      M      True
# 4       0001        11     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                         18         0.262139        3.251782  16959  ...
# 1                         14         0.262139        2.705068  25001  ...
# 2                          8         0.262139        3.756078  18105  ...
# 3                          7         0.262139        3.451943  18091  ...
# 4                         11         0.262139        3.522551  15807  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.422087          0.167829               27.0          0.106139
# 1          0.455864          0.097937               19.0          0.562157
# 2          0.702588          0.215688               26.0          0.654418
# 3          0.427423          0.162585               25.0          0.203475
# 4          0.554113          0.184134               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration  \
# 0                2.0          0.151046      0.166710
# 1                1.0          1.686070      1.686070
# 2                1.0          4.333857      4.333857
# 3                1.0          0.735873      0.735873
# 4                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  invalid_cause
# 0  [0.16670990000000074, 0.1353818999999703]                NaN            NaN
# 1                       [1.6860698000000411]                NaN            NaN
# 2                        [4.333857099999932]                NaN            NaN
# 3                       [0.7358727999999246]                NaN            NaN
# 4                                         []                NaN            NaN
#
# [5 rows x 41 columns]

# %%
metrics_df = add_metadata_to_metrics(metrics_df)
metrics_df.head()
# Out:
# /home/gianluca/Research/tmt-analysis/src/metadata/metadata_process.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   process_df = process_df[metadata_df['Nro de participante'] != 'Caso = ']
#   subject_id  trial_id trial_type gender  is_valid  trial_order_of_appearance  \
# 0       0001        18     PART_A      M      True                         18
# 1       0001        14     PART_B      M      True                         14
# 2       0001         8     PART_A      M      True                          8
# 3       0001         7     PART_B      M      True                          7
# 4       0001        11     PART_A      M      True                         11
#
#    speed_threshold  total_distance     rt  correct_targets_touches  ...  \
# 0         0.262139        3.251782  16959                     15.0  ...
# 1         0.262139        2.705068  25001                     14.0  ...
# 2         0.262139        3.756078  18105                     15.0  ...
# 3         0.262139        3.451943  18091                     15.0  ...
# 4         0.262139        3.522551  15807                     15.0  ...
#
#    hesitation_ratio  total_hesitations  average_duration  max_duration  \
# 0          0.106139                2.0          0.151046      0.166710
# 1          0.562157                1.0          1.686070      1.686070
# 2          0.654418                1.0          4.333857      4.333857
# 3          0.203475                1.0          0.735873      0.735873
# 4          0.000000                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  \
# 0  [0.16670990000000074, 0.1353818999999703]                0.0
# 1                       [1.6860698000000411]                0.0
# 2                        [4.333857099999932]                0.0
# 3                       [0.7358727999999246]                0.0
# 4                                         []                0.0
#
#    invalid_cause  sex  age  group
# 0            NaN    F   52     HC
# 1            NaN    F   52     HC
# 2            NaN    F   52     HC
# 3            NaN    F   52     HC
# 4            NaN    F   52     HC
#
# [5 rows x 43 columns]
