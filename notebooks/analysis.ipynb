# %%
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_default_parameters
from src.metadata.add_metadata import add_metadata_to_metrics

# %%
analysis = run_analysis_with_default_parameters()
metrics_df = analysis.get_metrics_dataframe()
metrics_df.head()
# Out:
# 2025-04-03 12:16:45,935 [INFO] root: Processing subject: 0001, group: control
# 2025-04-03 12:16:46,148 [INFO] root: Processing subject: 0002, group: control
# 2025-04-03 12:16:46,352 [INFO] root: Processing subject: 0003, group: MCI
# 2025-04-03 12:16:46,502 [INFO] root: Processing subject: 0004, group: MCI
# 2025-04-03 12:16:46,700 [INFO] root: Processing subject: 0005, group: MCI
# 2025-04-03 12:16:46,949 [INFO] root: Processing subject: 0006, group: control
# 2025-04-03 12:16:47,087 [INFO] root: Processing subject: 0007, group: control
# 2025-04-03 12:16:47,241 [INFO] root: Processing subject: 0008, group: MCI
# 2025-04-03 12:16:47,465 [INFO] root: Processing subject: 0009, group: MCI
# 2025-04-03 12:16:47,596 [INFO] root: Processing subject: 0010, group: control
# 2025-04-03 12:16:47,720 [INFO] root: Processing subject: 0011, group: MCI
# 2025-04-03 12:16:47,989 [INFO] root: Processing subject: 0012, group: MCI
# 2025-04-03 12:16:48,133 [INFO] root: Processing subject: 0013, group: MCI
# 2025-04-03 12:16:48,264 [INFO] root: Processing subject: 0014, group: control
# 2025-04-03 12:16:48,514 [INFO] root: Processing subject: 0015, group: MCI
# 2025-04-03 12:16:48,661 [INFO] root: Processing subject: 0016, group: MCI
# 2025-04-03 12:16:48,784 [INFO] root: Processing subject: 0017, group: MCI
# 2025-04-03 12:16:48,921 [INFO] root: Processing subject: 0018, group: control
# 2025-04-03 12:16:49,213 [INFO] root: Processing subject: 0019, group: MCI
# 2025-04-03 12:16:49,364 [INFO] root: Processing subject: 0020, group: MCI
# 2025-04-03 12:16:49,513 [INFO] root: Processing subject: 0021, group: control
# 2025-04-03 12:16:49,641 [INFO] root: Processing subject: 0022, group: control
# 2025-04-03 12:16:49,775 [INFO] root: Processing subject: 0023, group: control
# 2025-04-03 12:16:50,109 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-04-03 12:16:50,250 [INFO] root: Processing subject: 0025, group: MCI
# 2025-04-03 12:16:50,405 [INFO] root: Processing subject: 0026, group: control
# 2025-04-03 12:16:50,534 [INFO] root: Processing subject: 0027, group: MCI
# 2025-04-03 12:16:50,670 [INFO] root: Processing subject: 0028, group: control
# 2025-04-03 12:16:50,798 [INFO] root: Processing subject: 0029, group: control
# 2025-04-03 12:16:51,175 [INFO] root: Processing subject: 0030, group: control
# 2025-04-03 12:16:51,311 [INFO] root: Processing subject: 0031, group: control
# 2025-04-03 12:16:51,456 [INFO] root: Processing subject: 0032, group: control
# 2025-04-03 12:16:51,564 [INFO] root: Processing subject: 0033, group: control
# 2025-04-03 12:16:51,700 [INFO] root: Processing subject: 0034, group: control
# 2025-04-03 12:16:51,833 [INFO] root: Processing subject: 0035, group: control
# 2025-04-03 12:16:51,970 [INFO] root: Processing subject: 0036, group: control
# 2025-04-03 12:16:52,098 [INFO] root: Processing subject: 0037, group: control
# 2025-04-03 12:16:52,509 [INFO] root: Processing subject: 0038, group: control
# 2025-04-03 12:16:52,638 [INFO] root: Processing subject: 0039, group: control
# 2025-04-03 12:16:52,770 [INFO] root: Processing subject: 0040, group: control
# 2025-04-03 12:16:52,906 [INFO] root: Processing subject: 0041, group: control
# 2025-04-03 12:16:53,028 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-04-03 12:16:53,166 [INFO] root: Processing subject: 0043, group: control
# 2025-04-03 12:16:53,294 [INFO] root: Processing subject: 0044, group: control
# 2025-04-03 12:16:53,428 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-04-03 12:16:53,571 [INFO] root: Processing subject: 0046, group: MCI
# 2025-04-03 12:16:53,749 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-04-03 12:16:54,252 [INFO] root: Processing subject: 0048, group: MCI
# 2025-04-03 12:16:54,391 [INFO] root: Processing subject: 0049, group: MCI
# 2025-04-03 12:16:54,539 [INFO] root: Processing subject: 0050, group: MCI
# 2025-04-03 12:16:54,648 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-03 12:16:54,677 [INFO] root: Processing subject: 0051, group: MCI
# 2025-04-03 12:16:54,793 [INFO] root: Processing subject: 0052, group: MCI
# 2025-04-03 12:16:54,939 [INFO] root: Processing subject: 0053, group: MCI
# 2025-04-03 12:16:55,035 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-03 12:16:55,037 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-03 12:16:55,061 [INFO] root: Processing subject: 0054, group: MCI
# 2025-04-03 12:16:55,197 [INFO] root: Processing subject: 0055, group: MCI
# 2025-04-03 12:16:55,320 [INFO] root: Processing subject: 0056, group: control
# 2025-04-03 12:16:55,460 [INFO] root: Processing subject: 0057, group: MCI
# 2025-04-03 12:16:55,600 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-04-03 12:16:56,184 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-04-03 12:16:56,319 [INFO] root: Processing subject: 0060, group: MCI
# 2025-04-03 12:16:56,477 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-04-03 12:16:56,621 [INFO] root: Processing subject: 0062, group: MCI
# 2025-04-03 12:16:56,733 [INFO] root: Processing subject: 0063, group: control
# 2025-04-03 12:16:56,861 [INFO] root: Processing subject: 0064, group: MCI
# 2025-04-03 12:16:57,011 [INFO] root: Processing subject: 0065, group: MCI
# 2025-04-03 12:16:57,152 [INFO] root: Processing subject: 0066, group: MCI
# 2025-04-03 12:16:57,308 [INFO] root: Processing subject: 0067, group: MCI
# 2025-04-03 12:16:57,438 [INFO] root: Processing subject: 0068, group: MCI
# 2025-04-03 12:16:57,586 [INFO] root: Processing subject: 0069, group: MCI
# 2025-04-03 12:16:57,714 [INFO] root: Processing subject: 0070, group: control
# 2025-04-03 12:16:57,853 [INFO] root: Processing subject: 0071, group: control
# 2025-04-03 12:16:58,520 [INFO] root: Processing subject: 0072, group: MCI
# 2025-04-03 12:16:58,653 [INFO] root: Processing subject: 0073, group: MCI
# 2025-04-03 12:16:58,802 [INFO] root: Processing subject: 0074, group: control
# 2025-04-03 12:16:58,921 [INFO] root: Processing subject: 0075, group: MCI
# 2025-04-03 12:16:59,064 [INFO] root: Processing subject: 0076, group: MCI
# 2025-04-03 12:16:59,192 [INFO] root: Processing subject: 0077, group: MCI
# 2025-04-03 12:16:59,329 [INFO] root: Processing subject: 0078, group: control
# 2025-04-03 12:16:59,471 [INFO] root: Processing subject: 0079, group: control
# 2025-04-03 12:16:59,626 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-03 12:16:59,643 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-04-03 12:16:59,779 [INFO] root: Processing subject: 0081, group: MCI
# 2025-04-03 12:16:59,912 [INFO] root: Processing subject: 0082, group: MCI
# 2025-04-03 12:17:00,052 [INFO] root: Processing subject: 0083, group: control
# 2025-04-03 12:17:00,186 [INFO] root: Processing subject: 0084, group: control
# 2025-04-03 12:17:00,329 [INFO] root: Processing subject: 0085, group: control
# 2025-04-03 12:17:00,462 [INFO] root: Processing subject: 0086, group: control
# 2025-04-03 12:17:00,602 [INFO] root: Processing subject: 0087, group: control
# 2025-04-03 12:17:00,720 [INFO] root: Processing subject: 0088, group: MCI
# 2025-04-03 12:17:01,591 [INFO] root: Processing subject: 0089, group: control
# 2025-04-03 12:17:01,742 [INFO] root: Processing subject: 0090, group: control
# 2025-04-03 12:17:01,884 [INFO] root: Processing subject: 0091, group: control
# 2025-04-03 12:17:02,010 [INFO] root: Processing subject: 0092, group: MCI
# 2025-04-03 12:17:02,160 [INFO] root: Processing subject: 0093, group: MCI
# 2025-04-03 12:17:02,302 [INFO] root: Processing subject: 0094, group: MCI
# 2025-04-03 12:17:02,444 [INFO] root: Processing subject: 0095, group: control
# 2025-04-03 12:17:02,578 [INFO] root: Processing subject: 0096, group: MCI
# 2025-04-03 12:17:02,712 [INFO] root: Processing subject: 0097, group: MCI
# 2025-04-03 12:17:02,838 [INFO] root: Processing subject: 0098, group: MCI
# 2025-04-03 12:17:02,980 [INFO] root: Processing subject: 0099, group: MCI
# 2025-04-03 12:17:03,119 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-04-03 12:17:07,289 [ERROR] root: Error processing subject 0050
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 306, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(subject_id, subject, correct_targets_minimum,
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 86, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-03 12:17:07,417 [ERROR] root: Error processing subject 0053
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 306, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(subject_id, subject, correct_targets_minimum,
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 86, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-03 12:17:08,976 [ERROR] root: Error processing trial 12 for subject 0076: 'bool' object is not subscriptable
# 2025-04-03 12:17:08,977 [WARNING] root: Trial 12 of subject 0076 is not valid because of error.
# 2025-04-03 12:17:09,178 [ERROR] root: Error processing subject 0079
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 306, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(subject_id, subject, correct_targets_minimum,
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 86, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001        18     PART_A   35      M      True
# 1       0001        14     PART_B   35      M      True
# 2       0001         8     PART_A   35      M      True
# 3       0001         7     PART_B   35      M      True
# 4       0001        11     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                         18         0.262139        3.251782  16959  ...
# 1                         14         0.262139        2.705068  25001  ...
# 2                          8         0.262139        3.756078  18105  ...
# 3                          7         0.262139        3.451943  18091  ...
# 4                         11         0.262139        3.522551  15807  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.422087          0.167829               27.0          0.106139
# 1          0.455864          0.097937               19.0          0.562157
# 2          0.702588          0.215688               26.0          0.654418
# 3          0.427423          0.162585               25.0          0.203475
# 4          0.554113          0.184134               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration  \
# 0                2.0          0.151046      0.166710
# 1                1.0          1.686070      1.686070
# 2                1.0          4.333857      4.333857
# 3                1.0          0.735873      0.735873
# 4                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  invalid_cause
# 0  [0.16670990000000074, 0.1353818999999703]                0.0            NaN
# 1                       [1.6860698000000411]                0.0            NaN
# 2                        [4.333857099999932]                0.0            NaN
# 3                       [0.7358727999999246]                0.0            NaN
# 4                                         []                0.0            NaN
#
# [5 rows x 41 columns]
# Len of subjects: 99
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001        18     PART_A   35      M      True
# 1       0001        14     PART_B   35      M      True
# 2       0001         8     PART_A   35      M      True
# 3       0001         7     PART_B   35      M      True
# 4       0001        11     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                         18         0.262139        3.251782  16959  ...
# 1                         14         0.262139        2.705068  25001  ...
# 2                          8         0.262139        3.756078  18105  ...
# 3                          7         0.262139        3.451943  18091  ...
# 4                         11         0.262139        3.522551  15807  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.422087          0.167829               27.0          0.106139
# 1          0.455864          0.097937               19.0          0.562157
# 2          0.702588          0.215688               26.0          0.654418
# 3          0.427423          0.162585               25.0          0.203475
# 4          0.554113          0.184134               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration  \
# 0                2.0          0.151046      0.166710
# 1                1.0          1.686070      1.686070
# 2                1.0          4.333857      4.333857
# 3                1.0          0.735873      0.735873
# 4                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  invalid_cause
# 0  [0.16670990000000074, 0.1353818999999703]                0.0            NaN
# 1                       [1.6860698000000411]                0.0            NaN
# 2                        [4.333857099999932]                0.0            NaN
# 3                       [0.7358727999999246]                0.0            NaN
# 4                                         []                0.0            NaN
#
# [5 rows x 41 columns]

# %%
metrics_df = add_metadata_to_metrics(metrics_df)
metrics_df.head()
# Out:
# /home/gianluca/Research/tmt-analysis/src/metadata/metadata_process.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   process_df = process_df[metadata_df['Nro de participante'] != 'Caso = ']
#   subject_id  trial_id trial_type gender  is_valid  trial_order_of_appearance  \
# 0       0001        18     PART_A      M      True                         18
# 1       0001        14     PART_B      M      True                         14
# 2       0001         8     PART_A      M      True                          8
# 3       0001         7     PART_B      M      True                          7
# 4       0001        11     PART_A      M      True                         11
#
#    speed_threshold  total_distance     rt  correct_targets_touches  ...  \
# 0         0.262139        3.251782  16959                     15.0  ...
# 1         0.262139        2.705068  25001                     14.0  ...
# 2         0.262139        3.756078  18105                     15.0  ...
# 3         0.262139        3.451943  18091                     15.0  ...
# 4         0.262139        3.522551  15807                     15.0  ...
#
#    hesitation_ratio  total_hesitations  average_duration  max_duration  \
# 0          0.106139                2.0          0.151046      0.166710
# 1          0.562157                1.0          1.686070      1.686070
# 2          0.654418                1.0          4.333857      4.333857
# 3          0.203475                1.0          0.735873      0.735873
# 4          0.000000                0.0          0.000000      0.000000
#
#                           hesitation_periods  number_of_crosses  \
# 0  [0.16670990000000074, 0.1353818999999703]                0.0
# 1                       [1.6860698000000411]                0.0
# 2                        [4.333857099999932]                0.0
# 3                       [0.7358727999999246]                0.0
# 4                                         []                0.0
#
#    invalid_cause  sex  age  group
# 0            NaN    F   52     HC
# 1            NaN    F   52     HC
# 2            NaN    F   52     HC
# 3            NaN    F   52     HC
# 4            NaN    F   52     HC
#
# [5 rows x 43 columns]
