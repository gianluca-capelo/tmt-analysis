# %%
from src.hand_analysis.runner.run_hand_analysis import run_analysis_with_default_parameters
from src.metadata.add_metadata import add_metadata_to_metrics

# %%
analysis = run_analysis_with_default_parameters()
metrics_df = analysis.get_metrics_dataframe()
metrics_df.head()
# Out:
# 2025-04-05 09:45:49,633 [INFO] root: Processing subject: 0001, group: control
# 2025-04-05 09:45:49,845 [INFO] root: Processing subject: 0002, group: control
# 2025-04-05 09:45:50,052 [INFO] root: Processing subject: 0003, group: MCI
# 2025-04-05 09:45:50,198 [INFO] root: Processing subject: 0004, group: MCI
# 2025-04-05 09:45:50,397 [INFO] root: Processing subject: 0005, group: MCI
# 2025-04-05 09:45:50,638 [INFO] root: Processing subject: 0006, group: control
# 2025-04-05 09:45:50,778 [INFO] root: Processing subject: 0007, group: control
# 2025-04-05 09:45:50,949 [INFO] root: Processing subject: 0008, group: MCI
# 2025-04-05 09:45:51,194 [INFO] root: Processing subject: 0009, group: MCI
# 2025-04-05 09:45:51,331 [INFO] root: Processing subject: 0010, group: control
# 2025-04-05 09:45:51,460 [INFO] root: Processing subject: 0011, group: MCI
# 2025-04-05 09:45:51,723 [INFO] root: Processing subject: 0012, group: MCI
# 2025-04-05 09:45:51,867 [INFO] root: Processing subject: 0013, group: MCI
# 2025-04-05 09:45:52,006 [INFO] root: Processing subject: 0014, group: control
# 2025-04-05 09:45:52,260 [INFO] root: Processing subject: 0015, group: MCI
# 2025-04-05 09:45:52,429 [INFO] root: Processing subject: 0016, group: MCI
# 2025-04-05 09:45:52,553 [INFO] root: Processing subject: 0017, group: MCI
# 2025-04-05 09:45:52,693 [INFO] root: Processing subject: 0018, group: control
# 2025-04-05 09:45:52,991 [INFO] root: Processing subject: 0019, group: MCI
# 2025-04-05 09:45:53,134 [INFO] root: Processing subject: 0020, group: MCI
# 2025-04-05 09:45:53,283 [INFO] root: Processing subject: 0021, group: control
# 2025-04-05 09:45:53,426 [INFO] root: Processing subject: 0022, group: control
# 2025-04-05 09:45:53,571 [INFO] root: Processing subject: 0023, group: control
# 2025-04-05 09:45:53,919 [INFO] root: Processing subject: 0024, group: amnesic
# 2025-04-05 09:45:54,069 [INFO] root: Processing subject: 0025, group: MCI
# 2025-04-05 09:45:54,233 [INFO] root: Processing subject: 0026, group: control
# 2025-04-05 09:45:54,372 [INFO] root: Processing subject: 0027, group: MCI
# 2025-04-05 09:45:54,517 [INFO] root: Processing subject: 0028, group: control
# 2025-04-05 09:45:54,650 [INFO] root: Processing subject: 0029, group: control
# 2025-04-05 09:45:55,030 [INFO] root: Processing subject: 0030, group: control
# 2025-04-05 09:45:55,167 [INFO] root: Processing subject: 0031, group: control
# 2025-04-05 09:45:55,315 [INFO] root: Processing subject: 0032, group: control
# 2025-04-05 09:45:55,427 [INFO] root: Processing subject: 0033, group: control
# 2025-04-05 09:45:55,570 [INFO] root: Processing subject: 0034, group: control
# 2025-04-05 09:45:55,705 [INFO] root: Processing subject: 0035, group: control
# 2025-04-05 09:45:55,842 [INFO] root: Processing subject: 0036, group: control
# 2025-04-05 09:45:55,974 [INFO] root: Processing subject: 0037, group: control
# 2025-04-05 09:45:56,383 [INFO] root: Processing subject: 0038, group: control
# 2025-04-05 09:45:56,517 [INFO] root: Processing subject: 0039, group: control
# 2025-04-05 09:45:56,649 [INFO] root: Processing subject: 0040, group: control
# 2025-04-05 09:45:56,788 [INFO] root: Processing subject: 0041, group: control
# 2025-04-05 09:45:56,911 [INFO] root: Processing subject: 0042, group: amnesic
# 2025-04-05 09:45:57,053 [INFO] root: Processing subject: 0043, group: control
# 2025-04-05 09:45:57,185 [INFO] root: Processing subject: 0044, group: control
# 2025-04-05 09:45:57,325 [INFO] root: Processing subject: 0045, group: amnesic
# 2025-04-05 09:45:57,475 [INFO] root: Processing subject: 0046, group: MCI
# 2025-04-05 09:45:57,974 [INFO] root: Processing subject: 0047, group: amnesic
# 2025-04-05 09:45:58,119 [INFO] root: Processing subject: 0048, group: MCI
# 2025-04-05 09:45:58,272 [INFO] root: Processing subject: 0049, group: MCI
# 2025-04-05 09:45:58,435 [INFO] root: Processing subject: 0050, group: MCI
# 2025-04-05 09:45:58,549 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:45:58,579 [INFO] root: Processing subject: 0051, group: MCI
# 2025-04-05 09:45:58,699 [INFO] root: Processing subject: 0052, group: MCI
# 2025-04-05 09:45:58,844 [INFO] root: Processing subject: 0053, group: MCI
# 2025-04-05 09:45:58,943 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:45:58,945 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:45:58,970 [INFO] root: Processing subject: 0054, group: MCI
# 2025-04-05 09:45:59,113 [INFO] root: Processing subject: 0055, group: MCI
# 2025-04-05 09:45:59,239 [INFO] root: Processing subject: 0056, group: control
# 2025-04-05 09:45:59,380 [INFO] root: Processing subject: 0057, group: MCI
# 2025-04-05 09:45:59,979 [INFO] root: Processing subject: 0058, group: amnesic
# 2025-04-05 09:46:00,125 [INFO] root: Processing subject: 0059, group: amnesic
# 2025-04-05 09:46:00,259 [INFO] root: Processing subject: 0060, group: MCI
# 2025-04-05 09:46:00,407 [INFO] root: Processing subject: 0061, group: amnesic
# 2025-04-05 09:46:00,546 [INFO] root: Processing subject: 0062, group: MCI
# 2025-04-05 09:46:00,655 [INFO] root: Processing subject: 0063, group: control
# 2025-04-05 09:46:00,783 [INFO] root: Processing subject: 0064, group: MCI
# 2025-04-05 09:46:00,929 [INFO] root: Processing subject: 0065, group: MCI
# 2025-04-05 09:46:01,071 [INFO] root: Processing subject: 0066, group: MCI
# 2025-04-05 09:46:01,228 [INFO] root: Processing subject: 0067, group: MCI
# 2025-04-05 09:46:01,357 [INFO] root: Processing subject: 0068, group: MCI
# 2025-04-05 09:46:01,506 [INFO] root: Processing subject: 0069, group: MCI
# 2025-04-05 09:46:01,640 [INFO] root: Processing subject: 0070, group: control
# 2025-04-05 09:46:01,785 [INFO] root: Processing subject: 0071, group: control
# 2025-04-05 09:46:02,452 [INFO] root: Processing subject: 0072, group: MCI
# 2025-04-05 09:46:02,588 [INFO] root: Processing subject: 0073, group: MCI
# 2025-04-05 09:46:02,738 [INFO] root: Processing subject: 0074, group: control
# 2025-04-05 09:46:02,857 [INFO] root: Processing subject: 0075, group: MCI
# 2025-04-05 09:46:03,003 [INFO] root: Processing subject: 0076, group: MCI
# 2025-04-05 09:46:03,136 [INFO] root: Processing subject: 0077, group: MCI
# 2025-04-05 09:46:03,272 [INFO] root: Processing subject: 0078, group: control
# 2025-04-05 09:46:03,414 [INFO] root: Processing subject: 0079, group: control
# 2025-04-05 09:46:03,571 [WARNING] root: No target was hit in the cursor trail.
# 2025-04-05 09:46:03,589 [INFO] root: Processing subject: 0080, group: amnesic
# 2025-04-05 09:46:03,726 [INFO] root: Processing subject: 0081, group: MCI
# 2025-04-05 09:46:03,864 [INFO] root: Processing subject: 0082, group: MCI
# 2025-04-05 09:46:04,008 [INFO] root: Processing subject: 0083, group: control
# 2025-04-05 09:46:04,147 [INFO] root: Processing subject: 0084, group: control
# 2025-04-05 09:46:04,306 [INFO] root: Processing subject: 0085, group: control
# 2025-04-05 09:46:04,446 [INFO] root: Processing subject: 0086, group: control
# 2025-04-05 09:46:04,583 [INFO] root: Processing subject: 0087, group: control
# 2025-04-05 09:46:04,710 [INFO] root: Processing subject: 0088, group: MCI
# 2025-04-05 09:46:05,521 [INFO] root: Processing subject: 0089, group: control
# 2025-04-05 09:46:05,668 [INFO] root: Processing subject: 0090, group: control
# 2025-04-05 09:46:05,807 [INFO] root: Processing subject: 0091, group: control
# 2025-04-05 09:46:05,930 [INFO] root: Processing subject: 0092, group: MCI
# 2025-04-05 09:46:06,079 [INFO] root: Processing subject: 0093, group: MCI
# 2025-04-05 09:46:06,220 [INFO] root: Processing subject: 0094, group: MCI
# 2025-04-05 09:46:06,363 [INFO] root: Processing subject: 0095, group: control
# 2025-04-05 09:46:06,501 [INFO] root: Processing subject: 0096, group: MCI
# 2025-04-05 09:46:06,635 [INFO] root: Processing subject: 0097, group: MCI
# 2025-04-05 09:46:06,762 [INFO] root: Processing subject: 0098, group: MCI
# 2025-04-05 09:46:06,899 [INFO] root: Processing subject: 0099, group: MCI
# 2025-04-05 09:46:07,039 [INFO] root: Experiment loaded. Number of subjects: 99
# 2025-04-05 09:46:13,835 [ERROR] root: Error processing trial 12 for subject 0076: 'bool' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 89, in generate_rows_for_subject
#     trial_metrics = compute_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 239, in compute_trial_metrics
#     segmentation = calculate_segmentation_trial_metrics(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 321, in calculate_segmentation_trial_metrics
#     classified_positions = classify_cursor_positions_with_hesitation(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/segmentation/segmentation.py", line 93, in classify_cursor_positions_with_hesitation
#     over_target = over_target_flags[i][0]
# TypeError: 'bool' object is not subscriptable
# 2025-04-05 09:46:14,133 [ERROR] root: Error processing subject 0079: first_click_cursor_info no está definido en este trial.
# Traceback (most recent call last):
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 352, in calculate_and_save_metrics
#     subject_rows = generate_rows_for_subject(
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/metrics_calculator.py", line 47, in generate_rows_for_subject
#     if not trial.is_valid():
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 75, in is_valid
#     valid_length = self.is_valid_length()
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 84, in is_valid_length
#     return len(self.get_cursor_trail_from_start()) > 2
#   File "/home/gianluca/Research/neurotask/neurotask/neurotask/tmt/model/tmt_model.py", line 60, in get_cursor_trail_from_start
#     raise ValueError("first_click_cursor_info no está definido en este trial.")
# ValueError: first_click_cursor_info no está definido en este trial.
# 2025-04-05 09:46:15,948 [INFO] root: Metrics successfully saved to /home/gianluca/Research/tmt-analysis/data/hand_analysis/metrics.csv.
# Metrics DataFrame:
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                          2         0.262139        3.756078  18105  ...
# 1                          3         0.262139        3.451943  18091  ...
# 2                          4         0.262139        3.522551  15807  ...
# 3                          5         0.262139        3.349920  21544  ...
# 4                          6         0.262139        3.910085  18099  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.702588          0.215688               26.0          0.654418
# 1          0.427423          0.162585               25.0          0.203475
# 2          0.554113          0.184134               24.0          0.000000
# 3          0.455928          0.140833               26.0          0.000000
# 4          0.542851          0.153982               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    number_of_crosses  invalid_cause
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
# [5 rows x 41 columns]
# Len of subjects: 99
#   subject_id  trial_id trial_type  age gender  is_valid  \
# 0       0001         8     PART_A   35      M      True
# 1       0001         7     PART_B   35      M      True
# 2       0001        11     PART_A   35      M      True
# 3       0001        21     PART_B   35      M      True
# 4       0001         1     PART_A   35      M      True
#
#    trial_order_of_appearance  speed_threshold  total_distance     rt  ...  \
# 0                          2         0.262139        3.756078  18105  ...
# 1                          3         0.262139        3.451943  18091  ...
# 2                          4         0.262139        3.522551  15807  ...
# 3                          5         0.262139        3.349920  21544  ...
# 4                          6         0.262139        3.910085  18099  ...
#
#    travel_avg_speed  search_avg_speed  state_transitions  hesitation_ratio  \
# 0          0.702588          0.215688               26.0          0.654418
# 1          0.427423          0.162585               25.0          0.203475
# 2          0.554113          0.184134               24.0          0.000000
# 3          0.455928          0.140833               26.0          0.000000
# 4          0.542851          0.153982               24.0          0.000000
#
#    total_hesitations  average_duration  max_duration    hesitation_periods  \
# 0                1.0          4.333857      4.333857   [4.333857099999932]
# 1                1.0          0.735873      0.735873  [0.7358727999999246]
# 2                0.0          0.000000      0.000000                    []
# 3                0.0          0.000000      0.000000                    []
# 4                0.0          0.000000      0.000000                    []
#
#    number_of_crosses  invalid_cause
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
# [5 rows x 41 columns]

# %%
metrics_df = add_metadata_to_metrics(metrics_df)
metrics_df.head()
# Out:
# /home/gianluca/Research/tmt-analysis/src/metadata/metadata_process.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   process_df = process_df[metadata_df['Nro de participante'] != 'Caso = ']
#   subject_id  trial_id trial_type  is_valid  trial_order_of_appearance  \
# 0       0001         8     PART_A      True                          2
# 1       0001         7     PART_B      True                          3
# 2       0001        11     PART_A      True                          4
# 3       0001        21     PART_B      True                          5
# 4       0001         1     PART_A      True                          6
#
#    speed_threshold  total_distance     rt  correct_targets_touches  \
# 0         0.262139        3.756078  18105                     15.0
# 1         0.262139        3.451943  18091                     15.0
# 2         0.262139        3.522551  15807                     15.0
# 3         0.262139        3.349920  21544                     15.0
# 4         0.262139        3.910085  18099                     15.0
#
#    wrong_targets_touches  ...  hesitation_ratio  total_hesitations  \
# 0                    3.0  ...          0.654418                1.0
# 1                    3.0  ...          0.203475                1.0
# 2                    4.0  ...          0.000000                0.0
# 3                    4.0  ...          0.000000                0.0
# 4                    4.0  ...          0.000000                0.0
#
#    average_duration  max_duration    hesitation_periods  number_of_crosses  \
# 0          4.333857      4.333857   [4.333857099999932]                NaN
# 1          0.735873      0.735873  [0.7358727999999246]                NaN
# 2          0.000000      0.000000                    []                NaN
# 3          0.000000      0.000000                    []                NaN
# 4          0.000000      0.000000                    []                NaN
#
#    invalid_cause  sex  age  group
# 0            NaN    F   52     HC
# 1            NaN    F   52     HC
# 2            NaN    F   52     HC
# 3            NaN    F   52     HC
# 4            NaN    F   52     HC
#
# [5 rows x 42 columns]
